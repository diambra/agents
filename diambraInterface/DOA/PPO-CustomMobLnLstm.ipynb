# %%
gameFolder = "DOA++-MAME"

# %%
import sys, os
import time
timeDepSeed = int((time.time()-int(time.time()-0.5))*1000)

sys.path.append(os.path.join(os.path.abspath(''), '../'))   
sys.path.append(os.path.join(os.path.abspath(''), '../../../games',gameFolder))   

tensorBoardFolder = "./ppo2_TB_CustMobLnLstm/"
modelFolder = "ppo2_Model_CustMobLnLstm/"

os.makedirs(modelFolder, exist_ok=True)

# %%
from makeDiambraEnv import *

import tensorflow as tf

from customPolicies.customMobLstmPolicy import *

from stable_baselines import PPO2
from stable_baselines.common.evaluation import evaluate_policy
from stable_baselines.common.callbacks import BaseCallback

# %%
diambraKwargs = {}
diambraKwargs["roms_path"] = "../../../roms/MAMEToolkit/roms/"
diambraKwargs["binary_path"] = "../../../../customMAME/"
diambraKwargs["player"] = "P1"
diambraKwargs["frame_ratio"] = 3
#diambraKwargs["render"] =True
#diambraKwargs["throttle"] = False
#diambraKwargs["sound"] = False 
#diambraKwargs["character"] ="Random"
diambraKwargs["character"] = "Kasumi"

wrapperKwargs = {}
wrapperKwargs["frame_stack"] = 1
wrapperKwargs["clip_rewards"] = False
wrapperKwargs["normalize_rewards"] = True
wrapperKwargs["scale"] = True
wrapperKwargs["scale_mod"] = -1
wrapperKwargs["hwc_obs_resize"] = [224, 224, 3]

#keyToAdd = None
keyToAdd = []
keyToAdd.append("actionsBuf")
#keyToAdd.append("player")
keyToAdd.append("healthP1")
keyToAdd.append("healthP2")
keyToAdd.append("positionP1")
keyToAdd.append("positionP2")
#keyToAdd.append("winsP1")
#keyToAdd.append("winsP2")

numEnv=1

env = make_diambra_env(diambraMame, env_prefix="Train", num_env=numEnv, seed=timeDepSeed, 
                       continue_game = -2, diambra_kwargs = diambraKwargs, 
                       wrapper_kwargs = wrapperKwargs, key_to_add = keyToAdd)

# OR 
#env = make_diambra_env(diambraMame, num_env=2, seed=0, diambra_kwargs = diambraKwargs)
# Frame-stacking with 4 frames
#env = VecFrameStack(env, n_stack=4)
# Out:
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/common/misc_util.py:26: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# Env_id =  Train0
# Continue value =  -2
# Player = P1 , Character = Kasumi
# Noop action N =  11

# %%
print("Obs_space = ", env.observation_space)
print("Obs_space type = ", env.observation_space.dtype)
print("Obs_space high = ", env.observation_space.high)
print("Obs_space low = ", env.observation_space.low)

# %%
print("Act_space = ", env.action_space)
print("Act_space type = ", env.action_space.dtype)
print("Act_space n = ", env.action_space.n)

# %%
policyKwargs={}
policyKwargs["layers"] = [32, 64]
policyKwargs["encoder_embeddings_n"] = 512
policyKwargs["n_add_info"] = 148

# Initialize the model, 1 env
model = PPO2(CustomMobLstmPolicy, env, nminibatches=1, verbose=1, n_steps=16,
             tensorboard_log=tensorBoardFolder, policy_kwargs=policyKwargs, gamma = 0.94)

#OR

# Load the trained agent, 1 env
#model = PPO2.load(modelFolder+"770ksteps_action+_add", env=env, tensorboard_log=tensorBoardFolder, 
#                  policy_kwargs=policyKwargs, gamma = 0.94)
# Out:
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/alexpalms/Work/ArtificialTwin/Diambra/diambraengine/stableBaselines/diambraInterface/DOA/../customPolicies/customMobLstmPolicy.py:53: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f3a7acba978>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f3a7acba978>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f3a7acba978>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f3a7acba978>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f3a6bbca710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f3a6bbca710>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f3a6bbca710>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f3a6bbca710>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %%
# Train the agent
time_steps = 10000000
model.learn(total_timesteps=time_steps)
# Out:
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/common/base_class.py:1143: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Setting difficulty = 3
# Starting game
# Selecting Kasumi
# Waiting for fight to start
# ------------------------------------
# | approxkl           | 0.04804956  |
# | clipfrac           | 0.40625     |
# | explained_variance | -22.8       |
# | fps                | 0           |
# | n_updates          | 1           |
# | policy_entropy     | 2.448868    |
# | policy_loss        | -0.10010074 |
# | serial_timesteps   | 16          |
# | time_elapsed       | 3.1e-05     |
# | total_timesteps    | 16          |
# | value_loss         | 0.016424503 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.02482757  |
# | clipfrac           | 0.359375    |
# | explained_variance | -5.38       |
# | fps                | 9           |
# | n_updates          | 2           |
# | policy_entropy     | 2.4401488   |
# | policy_loss        | -0.09629903 |
# | serial_timesteps   | 32          |
# | time_elapsed       | 21.6        |
# | total_timesteps    | 32          |
# | value_loss         | 0.02727959  |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.022885464 |
# | clipfrac           | 0.40625     |
# | explained_variance | -38.9       |
# | fps                | 8           |
# | n_updates          | 3           |
# | policy_entropy     | 2.4293408   |
# | policy_loss        | -0.09769757 |
# | serial_timesteps   | 48          |
# | time_elapsed       | 23.4        |
# | total_timesteps    | 48          |
# | value_loss         | 0.025592733 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.018445801 |
# | clipfrac           | 0.203125    |
# | explained_variance | -53.5       |
# | fps                | 9           |
# | n_updates          | 4           |
# | policy_entropy     | 2.412056    |
# | policy_loss        | -0.08686331 |
# | serial_timesteps   | 64          |
# | time_elapsed       | 25.2        |
# | total_timesteps    | 64          |
# | value_loss         | 0.028176177 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.019567106 |
# | clipfrac           | 0.265625    |
# | explained_variance | -47.3       |
# | fps                | 9           |
# | n_updates          | 5           |
# | policy_entropy     | 2.4197297   |
# | policy_loss        | -0.0819072  |
# | serial_timesteps   | 80          |
# | time_elapsed       | 27          |
# | total_timesteps    | 80          |
# | value_loss         | 0.025349244 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.015958305 |
# | clipfrac           | 0.28125     |
# | explained_variance | -2.27       |
# | fps                | 9           |
# | n_updates          | 6           |
# | policy_entropy     | 2.3878717   |
# | policy_loss        | -0.08611901 |
# | serial_timesteps   | 96          |
# | time_elapsed       | 28.7        |
# | total_timesteps    | 96          |
# | value_loss         | 0.041977078 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.021100154 |
# | clipfrac           | 0.234375    |
# | explained_variance | -2.66       |
# | fps                | 9           |
# | n_updates          | 7           |
# | policy_entropy     | 2.3971548   |
# | policy_loss        | -0.08656776 |
# | serial_timesteps   | 112         |
# | time_elapsed       | 30.5        |
# | total_timesteps    | 112         |
# | value_loss         | 0.012852459 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.010622344 |
# | clipfrac           | 0.1875      |
# | explained_variance | -133        |
# | fps                | 9           |
# | n_updates          | 8           |
# | policy_entropy     | 2.3798385   |
# | policy_loss        | -0.06395054 |
# | serial_timesteps   | 128         |
# | time_elapsed       | 32.2        |
# | total_timesteps    | 128         |
# | value_loss         | 0.039558135 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.016406495  |
# | clipfrac           | 0.21875      |
# | explained_variance | -16.4        |
# | fps                | 6            |
# | n_updates          | 9            |
# | policy_entropy     | 2.3509       |
# | policy_loss        | -0.070409566 |
# | serial_timesteps   | 144          |
# | time_elapsed       | 34           |
# | total_timesteps    | 144          |
# | value_loss         | 0.024905063  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0076557635 |
# | clipfrac           | 0.125        |
# | explained_variance | -5.76        |
# | fps                | 9            |
# | n_updates          | 10           |
# | policy_entropy     | 2.3443928    |
# | policy_loss        | -0.062202074 |
# | serial_timesteps   | 160          |
# | time_elapsed       | 36.5         |
# | total_timesteps    | 160          |
# | value_loss         | 0.018742628  |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.008655148 |
# | clipfrac           | 0.1875      |
# | explained_variance | -19.8       |
# | fps                | 9           |
# | n_updates          | 11          |
# | policy_entropy     | 2.3234591   |
# | policy_loss        | -0.07239758 |
# | serial_timesteps   | 176         |
# | time_elapsed       | 38.2        |
# | total_timesteps    | 176         |
# | value_loss         | 0.020474996 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.022299113  |
# | clipfrac           | 0.296875     |
# | explained_variance | -11.9        |
# | fps                | 8            |
# | n_updates          | 12           |
# | policy_entropy     | 2.3722808    |
# | policy_loss        | -0.08063392  |
# | serial_timesteps   | 192          |
# | time_elapsed       | 40           |
# | total_timesteps    | 192          |
# | value_loss         | 0.0072572883 |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.020062495 |
# | clipfrac           | 0.265625    |
# | explained_variance | -223        |
# | fps                | 9           |
# | n_updates          | 13          |
# | policy_entropy     | 2.3841777   |
# | policy_loss        | -0.04882461 |
# | serial_timesteps   | 208         |
# | time_elapsed       | 41.8        |
# | total_timesteps    | 208         |
# | value_loss         | 0.026040409 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.010009509 |
# | clipfrac           | 0.140625    |
# | explained_variance | -3.16       |
# | fps                | 9           |
# | n_updates          | 14          |
# | policy_entropy     | 2.3800151   |
# | policy_loss        | -0.06146334 |
# | serial_timesteps   | 224         |
# | time_elapsed       | 43.5        |
# | total_timesteps    | 224         |
# | value_loss         | 0.008914187 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.011562805 |
# | clipfrac           | 0.171875    |
# | explained_variance | -2.49       |
# | fps                | 9           |
# | n_updates          | 15          |
# | policy_entropy     | 2.3823035   |
# | policy_loss        | -0.06958927 |
# | serial_timesteps   | 240         |
# | time_elapsed       | 45.3        |
# | total_timesteps    | 240         |
# | value_loss         | 0.040252283 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.005779632  |
# | clipfrac           | 0.09375      |
# | explained_variance | -112         |
# | fps                | 9            |
# | n_updates          | 16           |
# | policy_entropy     | 2.3600001    |
# | policy_loss        | -0.057951562 |
# | serial_timesteps   | 256          |
# | time_elapsed       | 47           |
# | total_timesteps    | 256          |
# | value_loss         | 0.009759077  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.012571447  |
# | clipfrac           | 0.1875       |
# | explained_variance | -10.7        |
# | fps                | 9            |
# | n_updates          | 17           |
# | policy_entropy     | 2.3843884    |
# | policy_loss        | -0.07014578  |
# | serial_timesteps   | 272          |
# | time_elapsed       | 48.8         |
# | total_timesteps    | 272          |
# | value_loss         | 0.0103231445 |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.017159529 |
# | clipfrac           | 0.21875     |
# | explained_variance | -56.1       |
# | fps                | 8           |
# | n_updates          | 18          |
# | policy_entropy     | 2.3928428   |
# | policy_loss        | -0.07962814 |
# | serial_timesteps   | 288         |
# | time_elapsed       | 50.5        |
# | total_timesteps    | 288         |
# | value_loss         | 0.016921049 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.020588495 |
# | clipfrac           | 0.28125     |
# | explained_variance | -4.51       |
# | fps                | 9           |
# | n_updates          | 19          |
# | policy_entropy     | 2.4156427   |
# | policy_loss        | -0.07504219 |
# | serial_timesteps   | 304         |
# | time_elapsed       | 52.3        |
# | total_timesteps    | 304         |
# | value_loss         | 0.021582026 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.011536942  |
# | clipfrac           | 0.15625      |
# | explained_variance | -0.273       |
# | fps                | 7            |
# | n_updates          | 20           |
# | policy_entropy     | 2.409931     |
# | policy_loss        | -0.063581266 |
# | serial_timesteps   | 320          |
# | time_elapsed       | 54.1         |
# | total_timesteps    | 320          |
# | value_loss         | 0.023550324  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.020864805  |
# | clipfrac           | 0.25         |
# | explained_variance | -27.8        |
# | fps                | 9            |
# | n_updates          | 21           |
# | policy_entropy     | 2.373611     |
# | policy_loss        | -0.085006714 |
# | serial_timesteps   | 336          |
# | time_elapsed       | 56.1         |
# | total_timesteps    | 336          |
# | value_loss         | 0.014422695  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.018379793  |
# | clipfrac           | 0.25         |
# | explained_variance | -17.4        |
# | fps                | 9            |
# | n_updates          | 22           |
# | policy_entropy     | 2.4313269    |
# | policy_loss        | -0.079748504 |
# | serial_timesteps   | 352          |
# | time_elapsed       | 57.9         |
# | total_timesteps    | 352          |
# | value_loss         | 0.006664416  |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.015857281 |
# | clipfrac           | 0.25        |
# | explained_variance | -86.3       |
# | fps                | 9           |
# | n_updates          | 23          |
# | policy_entropy     | 2.4020948   |
# | policy_loss        | -0.08389865 |
# | serial_timesteps   | 368         |
# | time_elapsed       | 59.6        |
# | total_timesteps    | 368         |
# | value_loss         | 0.006772324 |
# ------------------------------------
# Round done
# ------------------------------------
# | approxkl           | 0.010546884 |
# | clipfrac           | 0.15625     |
# | explained_variance | -1.27       |
# | fps                | 1           |
# | n_updates          | 24          |
# | policy_entropy     | 2.385367    |
# | policy_loss        | -0.06786467 |
# | serial_timesteps   | 384         |
# | time_elapsed       | 61.4        |
# | total_timesteps    | 384         |
# | value_loss         | 0.004116834 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.0050548567 |
# | clipfrac           | 0.0625       |
# | explained_variance | -8.82        |
# | fps                | 9            |
# | n_updates          | 25           |
# | policy_entropy     | 2.3901327    |
# | policy_loss        | -0.047851473 |
# | serial_timesteps   | 400          |
# | time_elapsed       | 69.4         |
# | total_timesteps    | 400          |
# | value_loss         | 0.009525893  |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.007859811 |
# | clipfrac           | 0.171875    |
# | explained_variance | -1.81       |
# | fps                | 9           |
# | n_updates          | 26          |
# | policy_entropy     | 2.4189937   |
# | policy_loss        | -0.0600749  |
# | serial_timesteps   | 416         |
# | time_elapsed       | 71.1        |
# | total_timesteps    | 416         |
# | value_loss         | 0.011560853 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.0076528834 |
# | clipfrac           | 0.125        |
# | explained_variance | -127         |
# | fps                | 9            |
# | n_updates          | 27           |
# | policy_entropy     | 2.409747     |
# | policy_loss        | -0.07007992  |
# | serial_timesteps   | 432          |
# | time_elapsed       | 72.9         |
# | total_timesteps    | 432          |
# | value_loss         | 0.014298892  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.007259229  |
# | clipfrac           | 0.140625     |
# | explained_variance | -21.1        |
# | fps                | 8            |
# | n_updates          | 28           |
# | policy_entropy     | 2.406949     |
# | policy_loss        | -0.051854894 |
# | serial_timesteps   | 448          |
# | time_elapsed       | 74.7         |
# | total_timesteps    | 448          |
# | value_loss         | 0.008937862  |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.004966315 |
# | clipfrac           | 0.078125    |
# | explained_variance | -0.719      |
# | fps                | 9           |
# | n_updates          | 29          |
# | policy_entropy     | 2.406927    |
# | policy_loss        | -0.06174603 |
# | serial_timesteps   | 464         |
# | time_elapsed       | 76.5        |
# | total_timesteps    | 464         |
# | value_loss         | 0.030991957 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.0048256107 |
# | clipfrac           | 0.0625       |
# | explained_variance | -50.3        |
# | fps                | 8            |
# | n_updates          | 30           |
# | policy_entropy     | 2.3950882    |
# | policy_loss        | -0.049001954 |
# | serial_timesteps   | 480          |
# | time_elapsed       | 78.2         |
# | total_timesteps    | 480          |
# | value_loss         | 0.03383387   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.006585449  |
# | clipfrac           | 0.09375      |
# | explained_variance | -13.5        |
# | fps                | 7            |
# | n_updates          | 31           |
# | policy_entropy     | 2.3757324    |
# | policy_loss        | -0.042530894 |
# | serial_timesteps   | 496          |
# | time_elapsed       | 80.1         |
# | total_timesteps    | 496          |
# | value_loss         | 0.008122577  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0059442883 |
# | clipfrac           | 0.09375      |
# | explained_variance | -52          |
# | fps                | 8            |
# | n_updates          | 32           |
# | policy_entropy     | 2.350719     |
# | policy_loss        | -0.036080565 |
# | serial_timesteps   | 512          |
# | time_elapsed       | 82.1         |
# | total_timesteps    | 512          |
# | value_loss         | 0.0043707895 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0019028491 |
# | clipfrac           | 0.0          |
# | explained_variance | -78.2        |
# | fps                | 8            |
# | n_updates          | 33           |
# | policy_entropy     | 2.349927     |
# | policy_loss        | -0.013919335 |
# | serial_timesteps   | 528          |
# | time_elapsed       | 83.9         |
# | total_timesteps    | 528          |
# | value_loss         | 0.0017254469 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0042931377 |
# | clipfrac           | 0.0625       |
# | explained_variance | -365         |
# | fps                | 8            |
# | n_updates          | 34           |
# | policy_entropy     | 2.3659062    |
# | policy_loss        | -0.041029174 |
# | serial_timesteps   | 544          |
# | time_elapsed       | 85.7         |
# | total_timesteps    | 544          |
# | value_loss         | 0.0015196751 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0008444673 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.237       |
# | fps                | 8            |
# | n_updates          | 35           |
# | policy_entropy     | 2.3490872    |
# | policy_loss        | -0.004430294 |
# | serial_timesteps   | 560          |
# | time_elapsed       | 87.6         |
# | total_timesteps    | 560          |
# | value_loss         | 0.017417192  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0029279424 |
# | clipfrac           | 0.03125      |
# | explained_variance | -0.396       |
# | fps                | 8            |
# | n_updates          | 36           |
# | policy_entropy     | 2.3295298    |
# | policy_loss        | -0.027485829 |
# | serial_timesteps   | 576          |
# | time_elapsed       | 89.6         |
# | total_timesteps    | 576          |
# | value_loss         | 0.0053347745 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.002302314  |
# | clipfrac           | 0.0          |
# | explained_variance | -2.84        |
# | fps                | 8            |
# | n_updates          | 37           |
# | policy_entropy     | 2.3254156    |
# | policy_loss        | -0.018788002 |
# | serial_timesteps   | 592          |
# | time_elapsed       | 91.4         |
# | total_timesteps    | 592          |
# | value_loss         | 0.0039456673 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.004255455  |
# | clipfrac           | 0.0625       |
# | explained_variance | -0.782       |
# | fps                | 8            |
# | n_updates          | 38           |
# | policy_entropy     | 2.3210275    |
# | policy_loss        | -0.03423303  |
# | serial_timesteps   | 608          |
# | time_elapsed       | 93.2         |
# | total_timesteps    | 608          |
# | value_loss         | 0.0053698765 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.003799221  |
# | clipfrac           | 0.0          |
# | explained_variance | -63.7        |
# | fps                | 8            |
# | n_updates          | 39           |
# | policy_entropy     | 2.3284464    |
# | policy_loss        | -0.044767134 |
# | serial_timesteps   | 624          |
# | time_elapsed       | 95           |
# | total_timesteps    | 624          |
# | value_loss         | 0.0017753345 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.004406219  |
# | clipfrac           | 0.078125     |
# | explained_variance | -88.2        |
# | fps                | 8            |
# | n_updates          | 40           |
# | policy_entropy     | 2.36512      |
# | policy_loss        | -0.039925955 |
# | serial_timesteps   | 640          |
# | time_elapsed       | 96.8         |
# | total_timesteps    | 640          |
# | value_loss         | 0.004280587  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0034309893 |
# | clipfrac           | 0.046875     |
# | explained_variance | -166         |
# | fps                | 8            |
# | n_updates          | 41           |
# | policy_entropy     | 2.366004     |
# | policy_loss        | -0.04048793  |
# | serial_timesteps   | 656          |
# | time_elapsed       | 98.6         |
# | total_timesteps    | 656          |
# | value_loss         | 0.0023467287 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0057608644 |
# | clipfrac           | 0.09375      |
# | explained_variance | -10.9        |
# | fps                | 9            |
# | n_updates          | 42           |
# | policy_entropy     | 2.3544993    |
# | policy_loss        | -0.050401624 |
# | serial_timesteps   | 672          |
# | time_elapsed       | 100          |
# | total_timesteps    | 672          |
# | value_loss         | 0.0025846031 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.005781718  |
# | clipfrac           | 0.09375      |
# | explained_variance | -46.4        |
# | fps                | 8            |
# | n_updates          | 43           |
# | policy_entropy     | 2.342541     |
# | policy_loss        | -0.04339232  |
# | serial_timesteps   | 688          |
# | time_elapsed       | 102          |
# | total_timesteps    | 688          |
# | value_loss         | 0.0061239526 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0069995886 |
# | clipfrac           | 0.109375     |
# | explained_variance | -0.417       |
# | fps                | 8            |
# | n_updates          | 44           |
# | policy_entropy     | 2.2923346    |
# | policy_loss        | -0.035830572 |
# | serial_timesteps   | 704          |
# | time_elapsed       | 104          |
# | total_timesteps    | 704          |
# | value_loss         | 0.013078174  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0056821303 |
# | clipfrac           | 0.046875     |
# | explained_variance | -103         |
# | fps                | 8            |
# | n_updates          | 45           |
# | policy_entropy     | 2.2278967    |
# | policy_loss        | -0.032921806 |
# | serial_timesteps   | 720          |
# | time_elapsed       | 106          |
# | total_timesteps    | 720          |
# | value_loss         | 0.0034512319 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0069167865 |
# | clipfrac           | 0.109375     |
# | explained_variance | -105         |
# | fps                | 8            |
# | n_updates          | 46           |
# | policy_entropy     | 2.2094932    |
# | policy_loss        | -0.059218183 |
# | serial_timesteps   | 736          |
# | time_elapsed       | 108          |
# | total_timesteps    | 736          |
# | value_loss         | 0.005994835  |
# -------------------------------------
# Stage done
# -------------------------------------
# | approxkl           | 0.0034435038 |
# | clipfrac           | 0.046875     |
# | explained_variance | -0.438       |
# | fps                | 1            |
# | n_updates          | 47           |
# | policy_entropy     | 2.2303634    |
# | policy_loss        | -0.054235924 |
# | serial_timesteps   | 752          |
# | time_elapsed       | 110          |
# | total_timesteps    | 752          |
# | value_loss         | 0.0059862453 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0013413597 |
# | clipfrac           | 0.0          |
# | explained_variance | -2.25        |
# | fps                | 9            |
# | n_updates          | 48           |
# | policy_entropy     | 2.2889524    |
# | policy_loss        | -0.018354058 |
# | serial_timesteps   | 768          |
# | time_elapsed       | 119          |
# | total_timesteps    | 768          |
# | value_loss         | 0.0032540555 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0046406556 |
# | clipfrac           | 0.046875     |
# | explained_variance | -1.74        |
# | fps                | 9            |
# | n_updates          | 49           |
# | policy_entropy     | 2.3188987    |
# | policy_loss        | -0.039074905 |
# | serial_timesteps   | 784          |
# | time_elapsed       | 121          |
# | total_timesteps    | 784          |
# | value_loss         | 0.0045317984 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0036918172 |
# | clipfrac           | 0.03125      |
# | explained_variance | -12.6        |
# | fps                | 9            |
# | n_updates          | 50           |
# | policy_entropy     | 2.3134942    |
# | policy_loss        | -0.029607292 |
# | serial_timesteps   | 800          |
# | time_elapsed       | 123          |
# | total_timesteps    | 800          |
# | value_loss         | 0.002776911  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.004535405  |
# | clipfrac           | 0.0625       |
# | explained_variance | -14.9        |
# | fps                | 9            |
# | n_updates          | 51           |
# | policy_entropy     | 2.2721565    |
# | policy_loss        | -0.032123003 |
# | serial_timesteps   | 816          |
# | time_elapsed       | 125          |
# | total_timesteps    | 816          |
# | value_loss         | 0.0017080969 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.006980625  |
# | clipfrac           | 0.078125     |
# | explained_variance | -39.6        |
# | fps                | 9            |
# | n_updates          | 52           |
# | policy_entropy     | 2.2192717    |
# | policy_loss        | -0.038558386 |
# | serial_timesteps   | 832          |
# | time_elapsed       | 126          |
# | total_timesteps    | 832          |
# | value_loss         | 0.004842918  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.006205465  |
# | clipfrac           | 0.09375      |
# | explained_variance | -0.658       |
# | fps                | 9            |
# | n_updates          | 53           |
# | policy_entropy     | 2.1980257    |
# | policy_loss        | -0.03419554  |
# | serial_timesteps   | 848          |
# | time_elapsed       | 128          |
# | total_timesteps    | 848          |
# | value_loss         | 0.0035459092 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0034582722 |
# | clipfrac           | 0.015625     |
# | explained_variance | -0.574       |
# | fps                | 9            |
# | n_updates          | 54           |
# | policy_entropy     | 2.25169      |
# | policy_loss        | -0.015800629 |
# | serial_timesteps   | 864          |
# | time_elapsed       | 130          |
# | total_timesteps    | 864          |
# | value_loss         | 0.023469854  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0027567868 |
# | clipfrac           | 0.0          |
# | explained_variance | -45.1        |
# | fps                | 8            |
# | n_updates          | 55           |
# | policy_entropy     | 2.312233     |
# | policy_loss        | -0.026236782 |
# | serial_timesteps   | 880          |
# | time_elapsed       | 132          |
# | total_timesteps    | 880          |
# | value_loss         | 0.001985724  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0025792764 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.632       |
# | fps                | 8            |
# | n_updates          | 56           |
# | policy_entropy     | 2.349142     |
# | policy_loss        | -0.023908798 |
# | serial_timesteps   | 896          |
# | time_elapsed       | 133          |
# | total_timesteps    | 896          |
# | value_loss         | 0.009833714  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0015416895 |
# | clipfrac           | 0.0          |
# | explained_variance | -29.3        |
# | fps                | 8            |
# | n_updates          | 57           |
# | policy_entropy     | 2.3648663    |
# | policy_loss        | -0.024078336 |
# | serial_timesteps   | 912          |
# | time_elapsed       | 135          |
# | total_timesteps    | 912          |
# | value_loss         | 0.008100785  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0025915643 |
# | clipfrac           | 0.015625     |
# | explained_variance | -0.157       |
# | fps                | 8            |
# | n_updates          | 58           |
# | policy_entropy     | 2.3703618    |
# | policy_loss        | -0.028882347 |
# | serial_timesteps   | 928          |
# | time_elapsed       | 137          |
# | total_timesteps    | 928          |
# | value_loss         | 0.012710484  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0019374515 |
# | clipfrac           | 0.015625     |
# | explained_variance | -0.216       |
# | fps                | 9            |
# | n_updates          | 59           |
# | policy_entropy     | 2.381904     |
# | policy_loss        | -0.032228254 |
# | serial_timesteps   | 944          |
# | time_elapsed       | 139          |
# | total_timesteps    | 944          |
# | value_loss         | 0.0012204761 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0021139842 |
# | clipfrac           | 0.015625     |
# | explained_variance | -3.43        |
# | fps                | 9            |
# | n_updates          | 60           |
# | policy_entropy     | 2.4132223    |
# | policy_loss        | -0.027785175 |
# | serial_timesteps   | 960          |
# | time_elapsed       | 141          |
# | total_timesteps    | 960          |
# | value_loss         | 0.0045360606 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0014993113 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.385       |
# | fps                | 9            |
# | n_updates          | 61           |
# | policy_entropy     | 2.4193764    |
# | policy_loss        | -0.027314391 |
# | serial_timesteps   | 976          |
# | time_elapsed       | 142          |
# | total_timesteps    | 976          |
# | value_loss         | 0.003912014  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0017308111 |
# | clipfrac           | 0.0          |
# | explained_variance | -5.97        |
# | fps                | 8            |
# | n_updates          | 62           |
# | policy_entropy     | 2.4093728    |
# | policy_loss        | -0.01913141  |
# | serial_timesteps   | 992          |
# | time_elapsed       | 144          |
# | total_timesteps    | 992          |
# | value_loss         | 0.0018192492 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00097221707 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0591       |
# | fps                | 8             |
# | n_updates          | 63            |
# | policy_entropy     | 2.3942702     |
# | policy_loss        | 0.001789324   |
# | serial_timesteps   | 1008          |
# | time_elapsed       | 146           |
# | total_timesteps    | 1008          |
# | value_loss         | 0.017759752   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0011496481 |
# | clipfrac           | 0.0          |
# | explained_variance | -6.06        |
# | fps                | 8            |
# | n_updates          | 64           |
# | policy_entropy     | 2.4026823    |
# | policy_loss        | -0.024633132 |
# | serial_timesteps   | 1024         |
# | time_elapsed       | 148          |
# | total_timesteps    | 1024         |
# | value_loss         | 0.0005343731 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00094373786 |
# | clipfrac           | 0.0           |
# | explained_variance | -10.3         |
# | fps                | 7             |
# | n_updates          | 65            |
# | policy_entropy     | 2.411986      |
# | policy_loss        | -0.019823372  |
# | serial_timesteps   | 1040          |
# | time_elapsed       | 150           |
# | total_timesteps    | 1040          |
# | value_loss         | 0.00094272627 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016665503  |
# | clipfrac           | 0.0           |
# | explained_variance | -15.2         |
# | fps                | 9             |
# | n_updates          | 66            |
# | policy_entropy     | 2.40186       |
# | policy_loss        | -0.012538333  |
# | serial_timesteps   | 1056          |
# | time_elapsed       | 152           |
# | total_timesteps    | 1056          |
# | value_loss         | 0.00092557556 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.001052113  |
# | clipfrac           | 0.0          |
# | explained_variance | -0.184       |
# | fps                | 9            |
# | n_updates          | 67           |
# | policy_entropy     | 2.3953755    |
# | policy_loss        | -0.010849521 |
# | serial_timesteps   | 1072         |
# | time_elapsed       | 154          |
# | total_timesteps    | 1072         |
# | value_loss         | 0.00710635   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0012578915 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.236       |
# | fps                | 9            |
# | n_updates          | 68           |
# | policy_entropy     | 2.3860438    |
# | policy_loss        | -0.018195864 |
# | serial_timesteps   | 1088         |
# | time_elapsed       | 155          |
# | total_timesteps    | 1088         |
# | value_loss         | 0.005001967  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0008052407 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.0342      |
# | fps                | 9            |
# | n_updates          | 69           |
# | policy_entropy     | 2.399667     |
# | policy_loss        | 0.017899118  |
# | serial_timesteps   | 1104         |
# | time_elapsed       | 157          |
# | total_timesteps    | 1104         |
# | value_loss         | 0.009863637  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00049889355 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.28         |
# | fps                | 8             |
# | n_updates          | 70            |
# | policy_entropy     | 2.4148943     |
# | policy_loss        | -0.010042708  |
# | serial_timesteps   | 1120          |
# | time_elapsed       | 159           |
# | total_timesteps    | 1120          |
# | value_loss         | 0.0005340581  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005181236 |
# | clipfrac           | 0.0          |
# | explained_variance | -105         |
# | fps                | 8            |
# | n_updates          | 71           |
# | policy_entropy     | 2.4173818    |
# | policy_loss        | -0.016282454 |
# | serial_timesteps   | 1136         |
# | time_elapsed       | 161          |
# | total_timesteps    | 1136         |
# | value_loss         | 0.0014359094 |
# -------------------------------------
# Round done
# --------------------------------------
# | approxkl           | 0.00040529776 |
# | clipfrac           | 0.0           |
# | explained_variance | -20           |
# | fps                | 1             |
# | n_updates          | 72            |
# | policy_entropy     | 2.4144418     |
# | policy_loss        | -0.012665113  |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 163           |
# | total_timesteps    | 1152          |
# | value_loss         | 0.0008680345  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00056778704 |
# | clipfrac           | 0.0           |
# | explained_variance | -11.5         |
# | fps                | 9             |
# | n_updates          | 73            |
# | policy_entropy     | 2.41213       |
# | policy_loss        | -0.013665032  |
# | serial_timesteps   | 1168          |
# | time_elapsed       | 171           |
# | total_timesteps    | 1168          |
# | value_loss         | 0.00039025128 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004788775  |
# | clipfrac           | 0.0           |
# | explained_variance | -46.3         |
# | fps                | 8             |
# | n_updates          | 74            |
# | policy_entropy     | 2.4203956     |
# | policy_loss        | -0.0073225275 |
# | serial_timesteps   | 1184          |
# | time_elapsed       | 173           |
# | total_timesteps    | 1184          |
# | value_loss         | 0.0005755869  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0001165264 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0679       |
# | fps                | 8            |
# | n_updates          | 75           |
# | policy_entropy     | 2.4238067    |
# | policy_loss        | -0.005530052 |
# | serial_timesteps   | 1200         |
# | time_elapsed       | 174          |
# | total_timesteps    | 1200         |
# | value_loss         | 0.019729141  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0003945665  |
# | clipfrac           | 0.0           |
# | explained_variance | -2.17         |
# | fps                | 9             |
# | n_updates          | 76            |
# | policy_entropy     | 2.4169443     |
# | policy_loss        | -0.014147153  |
# | serial_timesteps   | 1216          |
# | time_elapsed       | 176           |
# | total_timesteps    | 1216          |
# | value_loss         | 0.00022712254 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00044243288 |
# | clipfrac           | 0.0           |
# | explained_variance | -13.4         |
# | fps                | 9             |
# | n_updates          | 77            |
# | policy_entropy     | 2.4202247     |
# | policy_loss        | -0.016626762  |
# | serial_timesteps   | 1232          |
# | time_elapsed       | 178           |
# | total_timesteps    | 1232          |
# | value_loss         | 0.0009540381  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00036949158 |
# | clipfrac           | 0.0           |
# | explained_variance | -7.72         |
# | fps                | 8             |
# | n_updates          | 78            |
# | policy_entropy     | 2.412459      |
# | policy_loss        | -0.010759272  |
# | serial_timesteps   | 1248          |
# | time_elapsed       | 180           |
# | total_timesteps    | 1248          |
# | value_loss         | 0.0010513086  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00055819144 |
# | clipfrac           | 0.0           |
# | explained_variance | -44.6         |
# | fps                | 8             |
# | n_updates          | 79            |
# | policy_entropy     | 2.4140275     |
# | policy_loss        | -0.012623496  |
# | serial_timesteps   | 1264          |
# | time_elapsed       | 182           |
# | total_timesteps    | 1264          |
# | value_loss         | 0.0005458635  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00031756648 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0809        |
# | fps                | 9             |
# | n_updates          | 80            |
# | policy_entropy     | 2.404964      |
# | policy_loss        | -0.005543411  |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 183           |
# | total_timesteps    | 1280          |
# | value_loss         | 0.03318449    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0007733906  |
# | clipfrac           | 0.0           |
# | explained_variance | -104          |
# | fps                | 8             |
# | n_updates          | 81            |
# | policy_entropy     | 2.4086628     |
# | policy_loss        | -0.009700824  |
# | serial_timesteps   | 1296          |
# | time_elapsed       | 185           |
# | total_timesteps    | 1296          |
# | value_loss         | 0.00026734144 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002334983  |
# | clipfrac           | 0.0           |
# | explained_variance | -11.8         |
# | fps                | 9             |
# | n_updates          | 82            |
# | policy_entropy     | 2.4078603     |
# | policy_loss        | -0.0048983805 |
# | serial_timesteps   | 1312          |
# | time_elapsed       | 187           |
# | total_timesteps    | 1312          |
# | value_loss         | 0.0002837896  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00026362698 |
# | clipfrac           | 0.0           |
# | explained_variance | -280          |
# | fps                | 8             |
# | n_updates          | 83            |
# | policy_entropy     | 2.4198341     |
# | policy_loss        | -0.00814468   |
# | serial_timesteps   | 1328          |
# | time_elapsed       | 189           |
# | total_timesteps    | 1328          |
# | value_loss         | 0.0003474501  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00043080375 |
# | clipfrac           | 0.0           |
# | explained_variance | -87.4         |
# | fps                | 8             |
# | n_updates          | 84            |
# | policy_entropy     | 2.4272246     |
# | policy_loss        | -0.01712699   |
# | serial_timesteps   | 1344          |
# | time_elapsed       | 191           |
# | total_timesteps    | 1344          |
# | value_loss         | 0.00016184259 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0004171101 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.245       |
# | fps                | 9            |
# | n_updates          | 85           |
# | policy_entropy     | 2.4451256    |
# | policy_loss        | -0.011682708 |
# | serial_timesteps   | 1360         |
# | time_elapsed       | 192          |
# | total_timesteps    | 1360         |
# | value_loss         | 0.034699336  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0001577485 |
# | clipfrac           | 0.0          |
# | explained_variance | -85.5        |
# | fps                | 9            |
# | n_updates          | 86           |
# | policy_entropy     | 2.4513206    |
# | policy_loss        | -0.002388049 |
# | serial_timesteps   | 1376         |
# | time_elapsed       | 194          |
# | total_timesteps    | 1376         |
# | value_loss         | 0.0016707686 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00020295146 |
# | clipfrac           | 0.0           |
# | explained_variance | -11.4         |
# | fps                | 9             |
# | n_updates          | 87            |
# | policy_entropy     | 2.4468398     |
# | policy_loss        | -0.011516638  |
# | serial_timesteps   | 1392          |
# | time_elapsed       | 196           |
# | total_timesteps    | 1392          |
# | value_loss         | 0.0016004444  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00030730158 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.78         |
# | fps                | 8             |
# | n_updates          | 88            |
# | policy_entropy     | 2.453692      |
# | policy_loss        | -0.010839514  |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 198           |
# | total_timesteps    | 1408          |
# | value_loss         | 0.00094637036 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0003618456 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.296       |
# | fps                | 9            |
# | n_updates          | 89           |
# | policy_entropy     | 2.441372     |
# | policy_loss        | -0.009159371 |
# | serial_timesteps   | 1424         |
# | time_elapsed       | 199          |
# | total_timesteps    | 1424         |
# | value_loss         | 0.013655772  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00036292692 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.48         |
# | fps                | 8             |
# | n_updates          | 90            |
# | policy_entropy     | 2.433409      |
# | policy_loss        | -0.010206141  |
# | serial_timesteps   | 1440          |
# | time_elapsed       | 201           |
# | total_timesteps    | 1440          |
# | value_loss         | 0.0022398054  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0017377776 |
# | clipfrac           | 0.015625     |
# | explained_variance | 0.0336       |
# | fps                | 9            |
# | n_updates          | 91           |
# | policy_entropy     | 2.4098368    |
# | policy_loss        | -0.01730214  |
# | serial_timesteps   | 1456         |
# | time_elapsed       | 203          |
# | total_timesteps    | 1456         |
# | value_loss         | 0.010112714  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0036939355 |
# | clipfrac           | 0.03125      |
# | explained_variance | -1.21        |
# | fps                | 8            |
# | n_updates          | 92           |
# | policy_entropy     | 2.3727484    |
# | policy_loss        | -0.031375997 |
# | serial_timesteps   | 1472         |
# | time_elapsed       | 205          |
# | total_timesteps    | 1472         |
# | value_loss         | 0.0027121578 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.005453711  |
# | clipfrac           | 0.078125     |
# | explained_variance | -1.02        |
# | fps                | 7            |
# | n_updates          | 93           |
# | policy_entropy     | 2.2636027    |
# | policy_loss        | 0.003205143  |
# | serial_timesteps   | 1488         |
# | time_elapsed       | 207          |
# | total_timesteps    | 1488         |
# | value_loss         | 0.0031631459 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.004997214  |
# | clipfrac           | 0.046875     |
# | explained_variance | -0.0455      |
# | fps                | 8            |
# | n_updates          | 94           |
# | policy_entropy     | 2.2774634    |
# | policy_loss        | -0.048700895 |
# | serial_timesteps   | 1504         |
# | time_elapsed       | 209          |
# | total_timesteps    | 1504         |
# | value_loss         | 0.0132557405 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0033702874 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.903       |
# | fps                | 8            |
# | n_updates          | 95           |
# | policy_entropy     | 2.324523     |
# | policy_loss        | 0.005504489  |
# | serial_timesteps   | 1520         |
# | time_elapsed       | 211          |
# | total_timesteps    | 1520         |
# | value_loss         | 0.0032494883 |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.002141744 |
# | clipfrac           | 0.0         |
# | explained_variance | -0.344      |
# | fps                | 8           |
# | n_updates          | 96          |
# | policy_entropy     | 2.366994    |
# | policy_loss        | -0.02458549 |
# | serial_timesteps   | 1536        |
# | time_elapsed       | 212         |
# | total_timesteps    | 1536        |
# | value_loss         | 0.002265565 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.0017475868 |
# | clipfrac           | 0.0          |
# | explained_variance | -1.49        |
# | fps                | 8            |
# | n_updates          | 97           |
# ...
# | value_loss         | 0.0023750616 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.01552552   |
# | clipfrac           | 0.15625      |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -0.811       |
# | fps                | 9            |
# | n_updates          | 1331         |
# | policy_entropy     | 1.1190157    |
# | policy_loss        | -0.050686307 |
# | serial_timesteps   | 21296        |
# | time_elapsed       | 2.83e+03     |
# | total_timesteps    | 21296        |
# | value_loss         | 0.009819911  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.002746116   |
# | clipfrac           | 0.03125       |
# | ep_len_mean        | 5.09e+03      |
# | ep_reward_mean     | -3.5          |
# | explained_variance | -19.4         |
# | fps                | 9             |
# | n_updates          | 1332          |
# | policy_entropy     | 1.7251682     |
# | policy_loss        | -0.0069584176 |
# | serial_timesteps   | 21312         |
# | time_elapsed       | 2.83e+03      |
# | total_timesteps    | 21312         |
# | value_loss         | 0.0021226883  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.005036648  |
# | clipfrac           | 0.0625       |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -4.36        |
# | fps                | 8            |
# | n_updates          | 1333         |
# | policy_entropy     | 1.7426635    |
# | policy_loss        | -0.047089398 |
# | serial_timesteps   | 21328        |
# | time_elapsed       | 2.84e+03     |
# | total_timesteps    | 21328        |
# | value_loss         | 0.0035423175 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.24287455   |
# | clipfrac           | 0.375        |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -1.84        |
# | fps                | 9            |
# | n_updates          | 1334         |
# | policy_entropy     | 1.7632005    |
# | policy_loss        | -0.08775821  |
# | serial_timesteps   | 21344        |
# | time_elapsed       | 2.84e+03     |
# | total_timesteps    | 21344        |
# | value_loss         | 0.0068874005 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.030987803  |
# | clipfrac           | 0.25         |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -4.85        |
# | fps                | 9            |
# | n_updates          | 1335         |
# | policy_entropy     | 1.352316     |
# | policy_loss        | -0.050272807 |
# | serial_timesteps   | 21360        |
# | time_elapsed       | 2.84e+03     |
# | total_timesteps    | 21360        |
# | value_loss         | 0.006670434  |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.03296037  |
# | clipfrac           | 0.125       |
# | ep_len_mean        | 5.09e+03    |
# | ep_reward_mean     | -3.5        |
# | explained_variance | -0.115      |
# | fps                | 9           |
# | n_updates          | 1336        |
# | policy_entropy     | 0.94732463  |
# | policy_loss        | -0.04613266 |
# | serial_timesteps   | 21376       |
# | time_elapsed       | 2.84e+03    |
# | total_timesteps    | 21376       |
# | value_loss         | 0.007398896 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.011113301  |
# | clipfrac           | 0.125        |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -8.33        |
# | fps                | 9            |
# | n_updates          | 1337         |
# | policy_entropy     | 1.7792554    |
# | policy_loss        | -0.018706493 |
# | serial_timesteps   | 21392        |
# | time_elapsed       | 2.84e+03     |
# | total_timesteps    | 21392        |
# | value_loss         | 0.0067084297 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0029663525 |
# | clipfrac           | 0.046875     |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -3.84        |
# | fps                | 9            |
# | n_updates          | 1338         |
# | policy_entropy     | 1.355764     |
# | policy_loss        | -0.038075343 |
# | serial_timesteps   | 21408        |
# | time_elapsed       | 2.84e+03     |
# | total_timesteps    | 21408        |
# | value_loss         | 0.0033368003 |
# -------------------------------------
# Round done
# -------------------------------------
# | approxkl           | 0.10761914   |
# | clipfrac           | 0.34375      |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -0.0398      |
# | fps                | 1            |
# | n_updates          | 1339         |
# | policy_entropy     | 1.5249174    |
# | policy_loss        | -0.050508216 |
# | serial_timesteps   | 21424        |
# | time_elapsed       | 2.85e+03     |
# | total_timesteps    | 21424        |
# | value_loss         | 0.08863631   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.014809767  |
# | clipfrac           | 0.1875       |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | 0.00661      |
# | fps                | 9            |
# | n_updates          | 1340         |
# | policy_entropy     | 1.31872      |
# | policy_loss        | -0.06336908  |
# | serial_timesteps   | 21440        |
# | time_elapsed       | 2.85e+03     |
# | total_timesteps    | 21440        |
# | value_loss         | 0.0037705752 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0043177754 |
# | clipfrac           | 0.078125     |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -1.9         |
# | fps                | 9            |
# | n_updates          | 1341         |
# | policy_entropy     | 1.1023183    |
# | policy_loss        | -0.024293542 |
# | serial_timesteps   | 21456        |
# | time_elapsed       | 2.86e+03     |
# | total_timesteps    | 21456        |
# | value_loss         | 0.007792649  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.025144229  |
# | clipfrac           | 0.25         |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -192         |
# | fps                | 9            |
# | n_updates          | 1342         |
# | policy_entropy     | 1.8760123    |
# | policy_loss        | -0.049599454 |
# | serial_timesteps   | 21472        |
# | time_elapsed       | 2.86e+03     |
# | total_timesteps    | 21472        |
# | value_loss         | 0.0017861966 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.011860384  |
# | clipfrac           | 0.15625      |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -59.3        |
# | fps                | 9            |
# | n_updates          | 1343         |
# | policy_entropy     | 1.4307992    |
# | policy_loss        | -0.061520085 |
# | serial_timesteps   | 21488        |
# | time_elapsed       | 2.86e+03     |
# | total_timesteps    | 21488        |
# | value_loss         | 0.002752435  |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.020572023 |
# | clipfrac           | 0.203125    |
# | ep_len_mean        | 5.09e+03    |
# | ep_reward_mean     | -3.5        |
# | explained_variance | -0.187      |
# | fps                | 8           |
# | n_updates          | 1344        |
# | policy_entropy     | 1.4385363   |
# | policy_loss        | -0.06616342 |
# | serial_timesteps   | 21504       |
# | time_elapsed       | 2.86e+03    |
# | total_timesteps    | 21504       |
# | value_loss         | 0.020321917 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.018773038  |
# | clipfrac           | 0.234375     |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -177         |
# | fps                | 9            |
# | n_updates          | 1345         |
# | policy_entropy     | 1.4055438    |
# | policy_loss        | -0.060178652 |
# | serial_timesteps   | 21520        |
# | time_elapsed       | 2.86e+03     |
# | total_timesteps    | 21520        |
# | value_loss         | 0.0061138    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.014590388  |
# | clipfrac           | 0.140625     |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -0.47        |
# | fps                | 9            |
# | n_updates          | 1346         |
# | policy_entropy     | 1.4538732    |
# | policy_loss        | -0.05747518  |
# | serial_timesteps   | 21536        |
# | time_elapsed       | 2.87e+03     |
# | total_timesteps    | 21536        |
# | value_loss         | 0.0020195553 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.019542292  |
# | clipfrac           | 0.203125     |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -2.46        |
# | fps                | 8            |
# | n_updates          | 1347         |
# | policy_entropy     | 1.3218684    |
# | policy_loss        | -0.055064656 |
# | serial_timesteps   | 21552        |
# | time_elapsed       | 2.87e+03     |
# | total_timesteps    | 21552        |
# | value_loss         | 0.02664546   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.011126164  |
# | clipfrac           | 0.140625     |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -0.933       |
# | fps                | 9            |
# | n_updates          | 1348         |
# | policy_entropy     | 1.2022865    |
# | policy_loss        | -0.05462911  |
# | serial_timesteps   | 21568        |
# | time_elapsed       | 2.87e+03     |
# | total_timesteps    | 21568        |
# | value_loss         | 0.0062699798 |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.033604708 |
# | clipfrac           | 0.3125      |
# | ep_len_mean        | 5.09e+03    |
# | ep_reward_mean     | -3.5        |
# | explained_variance | -12.4       |
# | fps                | 8           |
# | n_updates          | 1349        |
# | policy_entropy     | 1.3932569   |
# | policy_loss        | -0.05538994 |
# | serial_timesteps   | 21584       |
# | time_elapsed       | 2.87e+03    |
# | total_timesteps    | 21584       |
# | value_loss         | 0.008502815 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.023124488 |
# | clipfrac           | 0.328125    |
# | ep_len_mean        | 5.09e+03    |
# | ep_reward_mean     | -3.5        |
# | explained_variance | 0.325       |
# | fps                | 9           |
# | n_updates          | 1350        |
# | policy_entropy     | 1.5164893   |
# | policy_loss        | -0.06417085 |
# | serial_timesteps   | 21600       |
# | time_elapsed       | 2.87e+03    |
# | total_timesteps    | 21600       |
# | value_loss         | 0.010942063 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.003738393 |
# | clipfrac           | 0.03125     |
# | ep_len_mean        | 5.09e+03    |
# | ep_reward_mean     | -3.5        |
# | explained_variance | 0.0142      |
# | fps                | 9           |
# | n_updates          | 1351        |
# | policy_entropy     | 1.7954589   |
# | policy_loss        | -0.02974905 |
# | serial_timesteps   | 21616       |
# | time_elapsed       | 2.87e+03    |
# | total_timesteps    | 21616       |
# | value_loss         | 0.008589804 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.013647549  |
# | clipfrac           | 0.15625      |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -4.17        |
# | fps                | 8            |
# | n_updates          | 1352         |
# | policy_entropy     | 1.9202447    |
# | policy_loss        | -0.043774977 |
# | serial_timesteps   | 21632        |
# | time_elapsed       | 2.88e+03     |
# | total_timesteps    | 21632        |
# | value_loss         | 0.0028098067 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.02112682   |
# | clipfrac           | 0.265625     |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -7.64        |
# | fps                | 9            |
# | n_updates          | 1353         |
# | policy_entropy     | 1.5110831    |
# | policy_loss        | -0.06716069  |
# | serial_timesteps   | 21648        |
# | time_elapsed       | 2.88e+03     |
# | total_timesteps    | 21648        |
# | value_loss         | 0.0032399925 |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.015087264 |
# | clipfrac           | 0.21875     |
# | ep_len_mean        | 5.09e+03    |
# | ep_reward_mean     | -3.5        |
# | explained_variance | -0.695      |
# | fps                | 8           |
# | n_updates          | 1354        |
# | policy_entropy     | 1.6614406   |
# | policy_loss        | -0.04379207 |
# | serial_timesteps   | 21664       |
# | time_elapsed       | 2.88e+03    |
# | total_timesteps    | 21664       |
# | value_loss         | 0.01427542  |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.011488721  |
# | clipfrac           | 0.078125     |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -2.72        |
# | fps                | 8            |
# | n_updates          | 1355         |
# | policy_entropy     | 1.5152594    |
# | policy_loss        | -0.043757487 |
# | serial_timesteps   | 21680        |
# | time_elapsed       | 2.88e+03     |
# | total_timesteps    | 21680        |
# | value_loss         | 0.003802301  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.014781244  |
# | clipfrac           | 0.125        |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -0.00242     |
# | fps                | 8            |
# | n_updates          | 1356         |
# | policy_entropy     | 1.6642795    |
# | policy_loss        | -0.056394905 |
# | serial_timesteps   | 21696        |
# | time_elapsed       | 2.88e+03     |
# | total_timesteps    | 21696        |
# | value_loss         | 0.023581453  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.004814552  |
# | clipfrac           | 0.046875     |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -12.3        |
# | fps                | 9            |
# | n_updates          | 1357         |
# | policy_entropy     | 1.4436713    |
# | policy_loss        | -0.030902825 |
# | serial_timesteps   | 21712        |
# | time_elapsed       | 2.88e+03     |
# | total_timesteps    | 21712        |
# | value_loss         | 0.0033980992 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0049062613 |
# | clipfrac           | 0.09375      |
# | ep_len_mean        | 5.09e+03     |
# | ep_reward_mean     | -3.5         |
# | explained_variance | -12.1        |
# | fps                | 9            |
# | n_updates          | 1358         |
# | policy_entropy     | 1.8414769    |
# | policy_loss        | -0.03345942  |
# | serial_timesteps   | 21728        |
# | time_elapsed       | 2.89e+03     |
# | total_timesteps    | 21728        |
# | value_loss         | 0.0013254015 |
# -------------------------------------

# %%
# Save the agent
model.save(modelFolder+"770ksteps_action+_add")

# %%
# %tensorboard --logdir ./tensorBoardFolder/

# %%
observation = env.reset()
states = None

while True:

    action, states = model.predict(observation, states, deterministic=False)
    action_prob = model.action_probability(observation, states)
    print("Action probabilities = ", action_prob)
    print("Max action = ", np.argmax(action_prob))
    print("Action = ", action)
    input("Pausa")
    
    observation, reward, done, info = env.step(action)
    if done:
        observation = env.reset()
        states = None
        
env.close()

# %%
observation = env.reset()
states = None

cumulativeEpRew = 0.0
cumulativeEpRewAll = []
cumulativeTotRew = 0.0

maxNumEp = 100
currNumEp = 0

while currNumEp < maxNumEp:

    action, states = model.predict(observation, states, deterministic=False)
    action_prob = model.action_probability(observation, states)
    print("Action probabilities = ", action_prob)
    print("Max action = ", np.argmax(action_prob))
    print("Action = ", action)
    
    observation, reward, done, info = env.step(action)
    
    cumulativeEpRew += reward
    
    if np.any(done):
        currNumEp += 1
        print("Ep. # = ", currNumEp)
        print("Ep. Cumulative Rew # = ", cumulativeEpRew)
        sys.stdout.flush()
        cumulativeEpRewAll.append(cumulativeEpRew)
        cumulativeTotRew += cumulativeEpRew
        cumulativeEpRew = 0.0

        observation = env.reset()
        states = None

print("Mean cumulative reward = ", cumulativeTotRew/maxNumEp)    
print("Mean cumulative reward = ", np.mean(cumulativeEpRewAll))    
print("Std cumulative reward = ", np.std(cumulativeEpRewAll))   
    
env.close()
