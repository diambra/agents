# %%
import gym
import tensorflow as tf

import os

import gym
import numpy as np

from stable_baselines import PPO2
from stable_baselines.bench import Monitor

from stable_baselines.common.policies import ActorCriticPolicy, register_policy, mlp_extractor, MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines.common.tf_layers import linear

# %%
# Custom MLP policy of three layers of size 128 each for the actor and 2 layers of 32 for the critic,
# with a MLP feature extractor
class CustomPolicyNew(ActorCriticPolicy):
    def __init__(self, sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse=False, **kwargs):
        super(CustomPolicyNew, self).__init__(sess, ob_space, ac_space, n_env, n_steps, n_batch, 
                                           reuse=reuse, scale=False)

        with tf.variable_scope("model", reuse=reuse):
            activ = tf.nn.relu

            pi_h, vf_h = mlp_extractor(tf.layers.flatten(self.processed_obs), 
                                               net_arch=[dict(vf=[64, 64], pi=[64, 64])],
                                               act_fun=tf.tanh, **kwargs)
            #extracted_features = tf.layers.flatten(extracted_features)

            #pi_h = extracted_features
            for i, layer_size in enumerate([128, 128, 128]):
                pi_h = activ(tf.layers.dense(pi_h, layer_size, name='pi_fc' + str(i)))
            pi_latent = pi_h

            #vf_h = extracted_features
            for i, layer_size in enumerate([32, 32]):
                vf_h = activ(tf.layers.dense(vf_h, layer_size, name='vf_fc' + str(i)))
            value_fn = tf.layers.dense(vf_h, 1, name='vf')
            vf_latent = vf_h

            self._proba_distribution, self._policy, self.q_value = \
                self.pdtype.proba_distribution_from_latent(pi_latent, vf_latent, init_scale=0.01)

        self._value_fn = value_fn
        self._setup_init()

    def step(self, obs, state=None, mask=None, deterministic=False):
        if deterministic:
            action, value, neglogp = self.sess.run([self.deterministic_action, self.value_flat, self.neglogp],
                                                   {self.obs_ph: obs})
        else:
            action, value, neglogp = self.sess.run([self.action, self.value_flat, self.neglogp],
                                                   {self.obs_ph: obs})
        return action, value, self.initial_state, neglogp

    def proba_step(self, obs, state=None, mask=None):
        return self.sess.run(self.policy_proba, {self.obs_ph: obs})

    def value(self, obs, state=None, mask=None):
        return self.sess.run(self.value_flat, {self.obs_ph: obs})

# %%
class CustomPolicy(ActorCriticPolicy):

    def __init__(self, sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse=False, layers=None, 
                 net_arch=None, act_fun=tf.tanh, feature_extraction="mlp", **kwargs):
        super(CustomPolicy, self).__init__(sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse=reuse,
                                                scale=(feature_extraction == "cnn"))

        self._kwargs_check(feature_extraction, kwargs)

        if layers is not None:
            warnings.warn("Usage of the `layers` parameter is deprecated! Use net_arch instead "
                          "(it has a different semantics though).", DeprecationWarning)
            if net_arch is not None:
                warnings.warn("The new `net_arch` parameter overrides the deprecated `layers` parameter!",
                              DeprecationWarning)

        if net_arch is None:
            if layers is None:
                layers = [64, 64]
            net_arch = [dict(vf=layers, pi=layers)]

        with tf.variable_scope("model", reuse=reuse):
            pi_latent, vf_latent = mlp_extractor(tf.layers.flatten(self.processed_obs), net_arch, act_fun)

            self._value_fn = linear(vf_latent, 'vf', 1)

            self._proba_distribution, self._policy, self.q_value = \
                self.pdtype.proba_distribution_from_latent(pi_latent, vf_latent, init_scale=0.01)

        self._setup_init()

    def step(self, obs, state=None, mask=None, deterministic=False):
        if deterministic:
            action, value, neglogp = self.sess.run([self.deterministic_action, self.value_flat, self.neglogp],
                                                   {self.obs_ph: obs})
        else:
            action, value, neglogp = self.sess.run([self.action, self.value_flat, self.neglogp],
                                                   {self.obs_ph: obs})
        return action, value, self.initial_state, neglogp

    def proba_step(self, obs, state=None, mask=None):
        return self.sess.run(self.policy_proba, {self.obs_ph: obs})

    def value(self, obs, state=None, mask=None):
        return self.sess.run(self.value_flat, {self.obs_ph: obs})

# %%
# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# %%
env = gym.make('CartPole-v1')
env = Monitor(env, log_dir)

model = PPO2(CustomPolicyNew, env, verbose=1)
# Out:
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From <ipython-input-2-1a5bcd0c05e1>:11: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9140ca4208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9140ca4208>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9140ca4208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9140ca4208>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From <ipython-input-2-1a5bcd0c05e1>:18: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c67fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c67fd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c67fd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c67fd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca4908>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca4908>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca4908>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca4908>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140ca44e0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c3cc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c3cc50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c3cc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c3cc50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9140c50208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9140c50208>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9140c50208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9140c50208>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140033ac8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f91384f92e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f91384f92e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f91384f92e8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f91384f92e8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f914005b9b0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f914005b9b0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f914005b9b0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f914005b9b0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c50208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c50208>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c50208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f9140c50208>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From /home/alexpalms/anaconda3/envs/diambra/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %%
# Train the agent
time_steps = 50000
model.learn(total_timesteps=time_steps)
# Out:
# --------------------------------------
# | approxkl           | 9.619993e-06  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 21.8          |
# | ep_reward_mean     | 21.8          |
# | explained_variance | 0.0345        |
# | fps                | 202           |
# | n_updates          | 1             |
# | policy_entropy     | 0.6931372     |
# | policy_loss        | -0.0006388412 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 4.43e-05      |
# | total_timesteps    | 128           |
# | value_loss         | 46.837788     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.3510906e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 23            |
# | ep_reward_mean     | 23            |
# | explained_variance | 0.00579       |
# | fps                | 818           |
# | n_updates          | 2             |
# | policy_entropy     | 0.6930676     |
# | policy_loss        | -0.0009091749 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 0.634         |
# | total_timesteps    | 256           |
# | value_loss         | 37.310608     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.853224e-06  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 20.5          |
# | ep_reward_mean     | 20.5          |
# | explained_variance | -0.0266       |
# | fps                | 786           |
# | n_updates          | 3             |
# | policy_entropy     | 0.6929916     |
# | policy_loss        | -0.0005039915 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.791         |
# | total_timesteps    | 384           |
# | value_loss         | 34.61281      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.71651e-06   |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 22            |
# | ep_reward_mean     | 22            |
# | explained_variance | -0.0584       |
# | fps                | 815           |
# | n_updates          | 4             |
# | policy_entropy     | 0.69285136    |
# | policy_loss        | 2.5637564e-05 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 0.954         |
# | total_timesteps    | 512           |
# | value_loss         | 36.44532      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.0801435e-06  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 21.2           |
# | ep_reward_mean     | 21.2           |
# | explained_variance | -0.121         |
# | fps                | 806            |
# | n_updates          | 5              |
# | policy_entropy     | 0.69291586     |
# | policy_loss        | -2.5916728e-05 |
# | serial_timesteps   | 640            |
# | time_elapsed       | 1.11           |
# | total_timesteps    | 640            |
# | value_loss         | 29.095505      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.160651e-06  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 20.4          |
# | ep_reward_mean     | 20.4          |
# | explained_variance | -0.232        |
# | fps                | 818           |
# | n_updates          | 6             |
# | policy_entropy     | 0.6928102     |
# | policy_loss        | -0.0003510228 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 1.27          |
# | total_timesteps    | 768           |
# | value_loss         | 20.069784     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.6142042e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 20.3          |
# | ep_reward_mean     | 20.3          |
# | explained_variance | -0.234        |
# | fps                | 855           |
# | n_updates          | 7             |
# | policy_entropy     | 0.6925397     |
# | policy_loss        | -0.0017079224 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 1.43          |
# | total_timesteps    | 896           |
# | value_loss         | 35.682213     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.1721072e-05  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 21.5           |
# | ep_reward_mean     | 21.5           |
# | explained_variance | -0.00631       |
# | fps                | 828            |
# | n_updates          | 8              |
# | policy_entropy     | 0.6926326      |
# | policy_loss        | -5.4601638e-05 |
# | serial_timesteps   | 1024           |
# | time_elapsed       | 1.58           |
# | total_timesteps    | 1024           |
# | value_loss         | 84.31068       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.9120667e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 21.9          |
# | ep_reward_mean     | 21.9          |
# | explained_variance | -0.337        |
# | fps                | 756           |
# | n_updates          | 9             |
# | policy_entropy     | 0.6912405     |
# | policy_loss        | -0.0005755974 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 1.73          |
# | total_timesteps    | 1152          |
# | value_loss         | 24.270672     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0019231525 |
# | clipfrac           | 0.0078125    |
# | ep_len_mean        | 21.9         |
# | ep_reward_mean     | 21.9         |
# | explained_variance | -0.29        |
# | fps                | 852          |
# | n_updates          | 10           |
# | policy_entropy     | 0.68075424   |
# | policy_loss        | -0.006338612 |
# | serial_timesteps   | 1280         |
# | time_elapsed       | 1.9          |
# | total_timesteps    | 1280         |
# | value_loss         | 28.078257    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 9.32532e-05   |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 22.6          |
# | ep_reward_mean     | 22.6          |
# | explained_variance | -0.0934       |
# | fps                | 827           |
# | n_updates          | 11            |
# | policy_entropy     | 0.68445987    |
# | policy_loss        | -0.0016387021 |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 2.05          |
# | total_timesteps    | 1408          |
# | value_loss         | 63.304794     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00066611543 |
# | clipfrac           | 0.001953125   |
# | ep_len_mean        | 22.2          |
# | ep_reward_mean     | 22.2          |
# | explained_variance | -0.242        |
# | fps                | 830           |
# | n_updates          | 12            |
# | policy_entropy     | 0.6805757     |
# | policy_loss        | -0.0016554353 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 2.21          |
# | total_timesteps    | 1536          |
# | value_loss         | 24.197598     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0013512913 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 22.6         |
# | ep_reward_mean     | 22.6         |
# | explained_variance | -0.169       |
# | fps                | 856          |
# | n_updates          | 13           |
# | policy_entropy     | 0.6732415    |
# | policy_loss        | -0.009425895 |
# | serial_timesteps   | 1664         |
# | time_elapsed       | 2.36         |
# | total_timesteps    | 1664         |
# | value_loss         | 43.730312    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0013603785  |
# | clipfrac           | 0.00390625    |
# | ep_len_mean        | 23.1          |
# | ep_reward_mean     | 23.1          |
# | explained_variance | -0.108        |
# | fps                | 849           |
# | n_updates          | 14            |
# | policy_entropy     | 0.6460255     |
# | policy_loss        | -0.0033893178 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 2.51          |
# | total_timesteps    | 1792          |
# | value_loss         | 48.045486     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0015209913  |
# | clipfrac           | 0.00390625    |
# | ep_len_mean        | 24.1          |
# | ep_reward_mean     | 24.1          |
# | explained_variance | -0.0623       |
# | fps                | 870           |
# | n_updates          | 15            |
# | policy_entropy     | 0.6374606     |
# | policy_loss        | -0.0061196806 |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 2.67          |
# | total_timesteps    | 1920          |
# | value_loss         | 73.45426      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00017307905  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 24.8           |
# | ep_reward_mean     | 24.8           |
# | explained_variance | 0.0105         |
# | fps                | 869            |
# | n_updates          | 16             |
# | policy_entropy     | 0.6405998      |
# | policy_loss        | -0.00078717695 |
# | serial_timesteps   | 2048           |
# | time_elapsed       | 2.81           |
# | total_timesteps    | 2048           |
# | value_loss         | 63.797295      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0006060024 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 26           |
# | ep_reward_mean     | 26           |
# | explained_variance | -0.163       |
# | fps                | 865          |
# | n_updates          | 17           |
# | policy_entropy     | 0.6620505    |
# | policy_loss        | 0.0034306026 |
# | serial_timesteps   | 2176         |
# | time_elapsed       | 2.96         |
# | total_timesteps    | 2176         |
# | value_loss         | 80.24889     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0010973858  |
# | clipfrac           | 0.005859375   |
# | ep_len_mean        | 27.2          |
# | ep_reward_mean     | 27.2          |
# | explained_variance | -0.0105       |
# | fps                | 861           |
# | n_updates          | 18            |
# | policy_entropy     | 0.65822214    |
# | policy_loss        | -0.0061715003 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 3.11          |
# | total_timesteps    | 2304          |
# | value_loss         | 79.870026     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016769033 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 27.9          |
# | ep_reward_mean     | 27.9          |
# | explained_variance | -0.0383       |
# | fps                | 852           |
# | n_updates          | 19            |
# | policy_entropy     | 0.63322705    |
# | policy_loss        | -0.0008975372 |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 3.26          |
# | total_timesteps    | 2432          |
# | value_loss         | 61.634277     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019051072 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 28.3          |
# | ep_reward_mean     | 28.3          |
# | explained_variance | -0.0274       |
# | fps                | 837           |
# | n_updates          | 20            |
# | policy_entropy     | 0.62486625    |
# | policy_loss        | -0.002293173  |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 3.41          |
# | total_timesteps    | 2560          |
# | value_loss         | 40.382286     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004843458   |
# | clipfrac           | 0.052734375   |
# | ep_len_mean        | 28.5          |
# | ep_reward_mean     | 28.5          |
# | explained_variance | -0.101        |
# | fps                | 799           |
# | n_updates          | 21            |
# | policy_entropy     | 0.6472041     |
# | policy_loss        | -0.0012572592 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 3.56          |
# | total_timesteps    | 2688          |
# | value_loss         | 96.29836      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0048100757 |
# | clipfrac           | 0.052734375  |
# | ep_len_mean        | 30.4         |
# | ep_reward_mean     | 30.4         |
# | explained_variance | -0.151       |
# | fps                | 849          |
# | n_updates          | 22           |
# | policy_entropy     | 0.65082234   |
# | policy_loss        | -0.013851133 |
# | serial_timesteps   | 2816         |
# | time_elapsed       | 3.72         |
# | total_timesteps    | 2816         |
# | value_loss         | 64.56551     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00056538323 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 30.4          |
# | ep_reward_mean     | 30.4          |
# | explained_variance | -0.172        |
# | fps                | 864           |
# | n_updates          | 23            |
# | policy_entropy     | 0.64028287    |
# | policy_loss        | -0.0020363168 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 3.88          |
# | total_timesteps    | 2944          |
# | value_loss         | 99.26683      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0046838513 |
# | clipfrac           | 0.0546875    |
# | ep_len_mean        | 31.9         |
# | ep_reward_mean     | 31.9         |
# | explained_variance | -0.145       |
# | fps                | 853          |
# | n_updates          | 24           |
# | policy_entropy     | 0.65908605   |
# | policy_loss        | 0.008182493  |
# | serial_timesteps   | 3072         |
# | time_elapsed       | 4.02         |
# | total_timesteps    | 3072         |
# | value_loss         | 79.76823     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0015489027  |
# | clipfrac           | 0.001953125   |
# | ep_len_mean        | 33.5          |
# | ep_reward_mean     | 33.5          |
# | explained_variance | 0.00982       |
# | fps                | 872           |
# | n_updates          | 25            |
# | policy_entropy     | 0.65501565    |
# | policy_loss        | -0.0057785353 |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 4.17          |
# | total_timesteps    | 3200          |
# | value_loss         | 66.62428      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018940063  |
# | clipfrac           | 0.009765625   |
# | ep_len_mean        | 34.4          |
# | ep_reward_mean     | 34.4          |
# | explained_variance | -0.138        |
# | fps                | 827           |
# | n_updates          | 26            |
# | policy_entropy     | 0.63750833    |
# | policy_loss        | -0.0026995987 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 4.32          |
# | total_timesteps    | 3328          |
# | value_loss         | 72.58928      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0006324613 |
# | clipfrac           | 0.001953125  |
# | ep_len_mean        | 35.1         |
# | ep_reward_mean     | 35.1         |
# | explained_variance | -0.144       |
# | fps                | 837          |
# | n_updates          | 27           |
# | policy_entropy     | 0.61545944   |
# | policy_loss        | -0.007089614 |
# | serial_timesteps   | 3456         |
# | time_elapsed       | 4.48         |
# | total_timesteps    | 3456         |
# | value_loss         | 60.92178     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0016668879  |
# | clipfrac           | 0.001953125   |
# | ep_len_mean        | 35.1          |
# | ep_reward_mean     | 35.1          |
# | explained_variance | -0.000598     |
# | fps                | 879           |
# | n_updates          | 28            |
# | policy_entropy     | 0.609893      |
# | policy_loss        | -0.0024014458 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 4.63          |
# | total_timesteps    | 3584          |
# | value_loss         | 76.046455     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0025512108 |
# | clipfrac           | 0.029296875  |
# | ep_len_mean        | 36.9         |
# | ep_reward_mean     | 36.9         |
# | explained_variance | 0.0374       |
# | fps                | 855          |
# | n_updates          | 29           |
# | policy_entropy     | 0.6028749    |
# | policy_loss        | 0.007958755  |
# | serial_timesteps   | 3712         |
# | time_elapsed       | 4.78         |
# | total_timesteps    | 3712         |
# | value_loss         | 69.82066     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.008809408  |
# | clipfrac           | 0.1171875    |
# | ep_len_mean        | 36.9         |
# | ep_reward_mean     | 36.9         |
# | explained_variance | 0.149        |
# | fps                | 857          |
# | n_updates          | 30           |
# | policy_entropy     | 0.6123012    |
# | policy_loss        | -0.009012096 |
# | serial_timesteps   | 3840         |
# | time_elapsed       | 4.93         |
# | total_timesteps    | 3840         |
# | value_loss         | 89.979294    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00094983005 |
# | clipfrac           | 0.00390625    |
# | ep_len_mean        | 38.7          |
# | ep_reward_mean     | 38.7          |
# | explained_variance | -0.0291       |
# | fps                | 848           |
# | n_updates          | 31            |
# | policy_entropy     | 0.62005264    |
# | policy_loss        | 0.007616415   |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 5.08          |
# | total_timesteps    | 3968          |
# | value_loss         | 64.04257      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012561076 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 39.8          |
# | ep_reward_mean     | 39.8          |
# | explained_variance | -0.0316       |
# | fps                | 817           |
# | n_updates          | 32            |
# | policy_entropy     | 0.61019146    |
# | policy_loss        | 0.00086507597 |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 5.23          |
# | total_timesteps    | 4096          |
# | value_loss         | 62.83199      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0003084441 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 41.2         |
# | ep_reward_mean     | 41.2         |
# | explained_variance | 0.178        |
# | fps                | 862          |
# | n_updates          | 33           |
# | policy_entropy     | 0.628169     |
# | policy_loss        | 0.0021973958 |
# | serial_timesteps   | 4224         |
# | time_elapsed       | 5.39         |
# | total_timesteps    | 4224         |
# | value_loss         | 72.11418     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 4.49084e-05  |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 41.7         |
# | ep_reward_mean     | 41.7         |
# | explained_variance | -0.0576      |
# | fps                | 863          |
# | n_updates          | 34           |
# | policy_entropy     | 0.61706513   |
# | policy_loss        | 0.0010611512 |
# | serial_timesteps   | 4352         |
# | time_elapsed       | 5.53         |
# | total_timesteps    | 4352         |
# | value_loss         | 62.188915    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00027337545 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 43.2          |
# | ep_reward_mean     | 43.2          |
# | explained_variance | 0.177         |
# | fps                | 869           |
# | n_updates          | 35            |
# | policy_entropy     | 0.6171107     |
# | policy_loss        | 0.0004165516  |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 5.68          |
# | total_timesteps    | 4480          |
# | value_loss         | 62.935356     |
# --------------------------------------
# ------------------------------------
# | approxkl           | 0.002769099 |
# | clipfrac           | 0.021484375 |
# | ep_len_mean        | 43.2        |
# | ep_reward_mean     | 43.2        |
# | explained_variance | 0.318       |
# | fps                | 862         |
# | n_updates          | 36          |
# | policy_entropy     | 0.63738364  |
# | policy_loss        | 0.00540925  |
# | serial_timesteps   | 4608        |
# | time_elapsed       | 5.83        |
# | total_timesteps    | 4608        |
# | value_loss         | 81.702515   |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.016333584  |
# | clipfrac           | 0.18554688   |
# | ep_len_mean        | 44.8         |
# | ep_reward_mean     | 44.8         |
# | explained_variance | 0.254        |
# | fps                | 881          |
# | n_updates          | 37           |
# | policy_entropy     | 0.6245284    |
# | policy_loss        | -0.013947604 |
# | serial_timesteps   | 4736         |
# | time_elapsed       | 5.98         |
# | total_timesteps    | 4736         |
# | value_loss         | 65.38979     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 6.942718e-05 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 46.4         |
# | ep_reward_mean     | 46.4         |
# | explained_variance | 0.0981       |
# | fps                | 820          |
# | n_updates          | 38           |
# | policy_entropy     | 0.6394339    |
# | policy_loss        | 0.0009989694 |
# | serial_timesteps   | 4864         |
# | time_elapsed       | 6.13         |
# | total_timesteps    | 4864         |
# | value_loss         | 54.18893     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00031878732 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 46.9          |
# | ep_reward_mean     | 46.9          |
# | explained_variance | 0.148         |
# | fps                | 815           |
# | n_updates          | 39            |
# | policy_entropy     | 0.63119096    |
# | policy_loss        | -0.0030620429 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 6.28          |
# | total_timesteps    | 4992          |
# | value_loss         | 54.11931      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0014677932 |
# | clipfrac           | 0.0078125    |
# | ep_len_mean        | 48.1         |
# | ep_reward_mean     | 48.1         |
# | explained_variance | 0.224        |
# | fps                | 733          |
# | n_updates          | 40           |
# | policy_entropy     | 0.5981766    |
# | policy_loss        | -0.006348367 |
# | serial_timesteps   | 5120         |
# | time_elapsed       | 6.44         |
# | total_timesteps    | 5120         |
# | value_loss         | 44.368744    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00031332648 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49.2          |
# | ep_reward_mean     | 49.2          |
# | explained_variance | 0.274         |
# | fps                | 814           |
# | n_updates          | 41            |
# | policy_entropy     | 0.617931      |
# | policy_loss        | 0.0005568983  |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 6.62          |
# | total_timesteps    | 5248          |
# | value_loss         | 52.21723      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 7.614413e-05 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 50.4         |
# | ep_reward_mean     | 50.4         |
# | explained_variance | 0.208        |
# | fps                | 815          |
# | n_updates          | 42           |
# | policy_entropy     | 0.60578525   |
# | policy_loss        | 9.828305e-05 |
# | serial_timesteps   | 5376         |
# | time_elapsed       | 6.77         |
# | total_timesteps    | 5376         |
# | value_loss         | 46.75456     |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 6.323393e-05   |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 50.7           |
# | ep_reward_mean     | 50.7           |
# | explained_variance | -0.0921        |
# | fps                | 856            |
# | n_updates          | 43             |
# | policy_entropy     | 0.57974184     |
# | policy_loss        | -0.00096004165 |
# | serial_timesteps   | 5504           |
# | time_elapsed       | 6.93           |
# | total_timesteps    | 5504           |
# | value_loss         | 38.918983      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00027350118 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 51.1          |
# | ep_reward_mean     | 51.1          |
# | explained_variance | 0.123         |
# | fps                | 870           |
# | n_updates          | 44            |
# | policy_entropy     | 0.6093341     |
# | policy_loss        | -0.003807397  |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 7.08          |
# | total_timesteps    | 5632          |
# | value_loss         | 44.80191      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023072469 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 52            |
# | ep_reward_mean     | 52            |
# | explained_variance | -0.0702       |
# | fps                | 839           |
# | n_updates          | 45            |
# | policy_entropy     | 0.5718069     |
# | policy_loss        | -0.0024054768 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 7.23          |
# | total_timesteps    | 5760          |
# | value_loss         | 46.901394     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0024790657 |
# | clipfrac           | 0.029296875  |
# | ep_len_mean        | 52           |
# | ep_reward_mean     | 52           |
# | explained_variance | 0.29         |
# | fps                | 811          |
# | n_updates          | 46           |
# | policy_entropy     | 0.6263214    |
# | policy_loss        | -0.002653458 |
# | serial_timesteps   | 5888         |
# | time_elapsed       | 7.38         |
# | total_timesteps    | 5888         |
# | value_loss         | 71.89594     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0016910178  |
# | clipfrac           | 0.009765625   |
# | ep_len_mean        | 54.5          |
# | ep_reward_mean     | 54.5          |
# | explained_variance | 0.242         |
# | fps                | 850           |
# | n_updates          | 47            |
# | policy_entropy     | 0.55426717    |
# | policy_loss        | -0.0029462145 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 7.54          |
# | total_timesteps    | 6016          |
# | value_loss         | 38.412678     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024510673 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 54.5          |
# | ep_reward_mean     | 54.5          |
# | explained_variance | -0.0267       |
# | fps                | 880           |
# | n_updates          | 48            |
# | policy_entropy     | 0.60023135    |
# | policy_loss        | -0.0005780681 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 7.69          |
# | total_timesteps    | 6144          |
# | value_loss         | 74.61664      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0033045688 |
# | clipfrac           | 0.015625     |
# | ep_len_mean        | 56.8         |
# | ep_reward_mean     | 56.8         |
# | explained_variance | 0.238        |
# | fps                | 868          |
# | n_updates          | 49           |
# | policy_entropy     | 0.6165869    |
# | policy_loss        | 0.004236516  |
# | serial_timesteps   | 6272         |
# | time_elapsed       | 7.84         |
# | total_timesteps    | 6272         |
# | value_loss         | 51.379787    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00013920292 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 57.8          |
# | ep_reward_mean     | 57.8          |
# | explained_variance | 0.0737        |
# | fps                | 860           |
# | n_updates          | 50            |
# | policy_entropy     | 0.5966259     |
# | policy_loss        | -0.001998833  |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 7.99          |
# | total_timesteps    | 6400          |
# | value_loss         | 37.44         |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004920947  |
# | clipfrac           | 0.001953125   |
# | ep_len_mean        | 58.3          |
# | ep_reward_mean     | 58.3          |
# | explained_variance | 0.381         |
# | fps                | 863           |
# | n_updates          | 51            |
# | policy_entropy     | 0.58528024    |
# | policy_loss        | -0.0035109508 |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 8.13          |
# | total_timesteps    | 6528          |
# | value_loss         | 45.259586     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.005845534  |
# | clipfrac           | 0.1015625    |
# | ep_len_mean        | 58.8         |
# | ep_reward_mean     | 58.8         |
# | explained_variance | 0.0672       |
# | fps                | 826          |
# | n_updates          | 52           |
# | policy_entropy     | 0.5756537    |
# | policy_loss        | -0.008041938 |
# | serial_timesteps   | 6656         |
# | time_elapsed       | 8.28         |
# | total_timesteps    | 6656         |
# | value_loss         | 70.34627     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0006846593  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 60.8          |
# | ep_reward_mean     | 60.8          |
# | explained_variance | 0.538         |
# | fps                | 783           |
# | n_updates          | 53            |
# | policy_entropy     | 0.56374156    |
# | policy_loss        | -3.627478e-05 |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 8.44          |
# | total_timesteps    | 6784          |
# | value_loss         | 39.500214     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00085714355 |
# | clipfrac           | 0.001953125   |
# | ep_len_mean        | 62            |
# | ep_reward_mean     | 62            |
# | explained_variance | 0.385         |
# | fps                | 739           |
# | n_updates          | 54            |
# | policy_entropy     | 0.57539034    |
# | policy_loss        | -0.0075067263 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 8.6           |
# | total_timesteps    | 6912          |
# | value_loss         | 42.508396     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.699507e-05  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 62.7          |
# | ep_reward_mean     | 62.7          |
# | explained_variance | 0.128         |
# | fps                | 761           |
# | n_updates          | 55            |
# | policy_entropy     | 0.5645705     |
# | policy_loss        | 0.00069904106 |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 8.78          |
# | total_timesteps    | 7040          |
# | value_loss         | 48.623272     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00031484023 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 64.4          |
# | ep_reward_mean     | 64.4          |
# | explained_variance | 0.728         |
# | fps                | 833           |
# | n_updates          | 56            |
# | policy_entropy     | 0.6001146     |
# | policy_loss        | -0.0030527238 |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 8.95          |
# | total_timesteps    | 7168          |
# | value_loss         | 38.972168     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0014702982 |
# | clipfrac           | 0.0078125    |
# | ep_len_mean        | 64.4         |
# | ep_reward_mean     | 64.4         |
# | explained_variance | 0.204        |
# | fps                | 867          |
# | n_updates          | 57           |
# | policy_entropy     | 0.58822274   |
# | policy_loss        | 0.0025997446 |
# | serial_timesteps   | 7296         |
# | time_elapsed       | 9.1          |
# | total_timesteps    | 7296         |
# | value_loss         | 63.646927    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.002365904  |
# | clipfrac           | 0.0234375    |
# | ep_len_mean        | 64.4         |
# | ep_reward_mean     | 64.4         |
# | explained_variance | 0.601        |
# | fps                | 877          |
# | n_updates          | 58           |
# | policy_entropy     | 0.6178051    |
# | policy_loss        | -0.003365024 |
# | serial_timesteps   | 7424         |
# | time_elapsed       | 9.25         |
# | total_timesteps    | 7424         |
# | value_loss         | 53.675552    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.002082535  |
# | clipfrac           | 0.03125      |
# | ep_len_mean        | 67.7         |
# | ep_reward_mean     | 67.7         |
# | explained_variance | 0.474        |
# | fps                | 863          |
# | n_updates          | 59           |
# | policy_entropy     | 0.5978651    |
# | policy_loss        | 0.0044583557 |
# | serial_timesteps   | 7552         |
# | time_elapsed       | 9.4          |
# | total_timesteps    | 7552         |
# | value_loss         | 30.662949    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 2.2453469e-05  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 68.7           |
# | ep_reward_mean     | 68.7           |
# | explained_variance | 0.0559         |
# | fps                | 831            |
# | n_updates          | 60             |
# | policy_entropy     | 0.5692442      |
# | policy_loss        | -0.00036673085 |
# | serial_timesteps   | 7680           |
# | time_elapsed       | 9.54           |
# | total_timesteps    | 7680           |
# | value_loss         | 48.65429       |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0005953453 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 69.7         |
# | ep_reward_mean     | 69.7         |
# | explained_variance | 0.088        |
# | fps                | 866          |
# | n_updates          | 61           |
# | policy_entropy     | 0.5571782    |
# | policy_loss        | -0.004538995 |
# | serial_timesteps   | 7808         |
# | time_elapsed       | 9.7          |
# | total_timesteps    | 7808         |
# | value_loss         | 47.046402    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0026700404  |
# | clipfrac           | 0.015625      |
# | ep_len_mean        | 70.9          |
# | ep_reward_mean     | 70.9          |
# | explained_variance | 0.115         |
# | fps                | 829           |
# | n_updates          | 62            |
# | policy_entropy     | 0.5797389     |
# | policy_loss        | -0.0030489974 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 9.85          |
# | total_timesteps    | 7936          |
# | value_loss         | 46.804325     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.008949659  |
# | clipfrac           | 0.14648438   |
# | ep_len_mean        | 72.3         |
# | ep_reward_mean     | 72.3         |
# | explained_variance | 0.242        |
# | fps                | 850          |
# | n_updates          | 63           |
# | policy_entropy     | 0.5797962    |
# | policy_loss        | 0.0017190436 |
# | serial_timesteps   | 8064         |
# | time_elapsed       | 10           |
# | total_timesteps    | 8064         |
# | value_loss         | 47.182182    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0020437215 |
# | clipfrac           | 0.0234375    |
# | ep_len_mean        | 72.7         |
# | ep_reward_mean     | 72.7         |
# | explained_variance | -0.0758      |
# | fps                | 857          |
# | n_updates          | 64           |
# | policy_entropy     | 0.54214525   |
# | policy_loss        | -0.003068911 |
# | serial_timesteps   | 8192         |
# | time_elapsed       | 10.2         |
# | total_timesteps    | 8192         |
# | value_loss         | 54.94392     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00021839139 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 73.4          |
# | ep_reward_mean     | 73.4          |
# | explained_variance | 0.094         |
# | fps                | 862           |
# | n_updates          | 65            |
# | policy_entropy     | 0.58425784    |
# | policy_loss        | -0.0047385306 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 10.3          |
# | total_timesteps    | 8320          |
# | value_loss         | 63.05796      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0013407534 |
# | clipfrac           | 0.0078125    |
# | ep_len_mean        | 75.4         |
# | ep_reward_mean     | 75.4         |
# | explained_variance | 0.0522       |
# | fps                | 862          |
# | n_updates          | 66           |
# | policy_entropy     | 0.58227926   |
# | policy_loss        | 0.0012225738 |
# | serial_timesteps   | 8448         |
# | time_elapsed       | 10.5         |
# | total_timesteps    | 8448         |
# | value_loss         | 55.175766    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00014105627 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 75.9          |
# | ep_reward_mean     | 75.9          |
# | explained_variance | 0.443         |
# | fps                | 831           |
# | n_updates          | 67            |
# | policy_entropy     | 0.5846365     |
# | policy_loss        | -0.0028135916 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 10.6          |
# | total_timesteps    | 8576          |
# | value_loss         | 39.74658      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0065055653  |
# | clipfrac           | 0.0625        |
# | ep_len_mean        | 75.9          |
# | ep_reward_mean     | 75.9          |
# | explained_variance | 0.653         |
# | fps                | 849           |
# | n_updates          | 68            |
# | policy_entropy     | 0.57685786    |
# | policy_loss        | -0.0073687737 |
# | serial_timesteps   | 8704          |
# | time_elapsed       | 10.8          |
# | total_timesteps    | 8704          |
# | value_loss         | 45.758183     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0028888527  |
# | clipfrac           | 0.037109375   |
# | ep_len_mean        | 77.1          |
# | ep_reward_mean     | 77.1          |
# | explained_variance | 0.468         |
# | fps                | 878           |
# | n_updates          | 69            |
# | policy_entropy     | 0.5843613     |
# | policy_loss        | -0.0067423023 |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 10.9          |
# | total_timesteps    | 8832          |
# | value_loss         | 46.351974     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0032171947 |
# | clipfrac           | 0.025390625  |
# | ep_len_mean        | 77.1         |
# | ep_reward_mean     | 77.1         |
# | explained_variance | 0.109        |
# | fps                | 878          |
# | n_updates          | 70           |
# | policy_entropy     | 0.5552767    |
# | policy_loss        | -0.004921195 |
# | serial_timesteps   | 8960         |
# | time_elapsed       | 11.1         |
# | total_timesteps    | 8960         |
# | value_loss         | 43.077873    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0015438406 |
# | clipfrac           | 0.009765625  |
# | ep_len_mean        | 80.2         |
# | ep_reward_mean     | 80.2         |
# | explained_variance | 0.0801       |
# | fps                | 833          |
# | n_updates          | 71           |
# | policy_entropy     | 0.5217786    |
# | policy_loss        | 0.0015695677 |
# | serial_timesteps   | 9088         |
# | time_elapsed       | 11.2         |
# | total_timesteps    | 9088         |
# | value_loss         | 79.84868     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 5.0230592e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 80.7          |
# | ep_reward_mean     | 80.7          |
# | explained_variance | -0.0056       |
# | fps                | 644           |
# | n_updates          | 72            |
# | policy_entropy     | 0.53885233    |
# | policy_loss        | 0.0011028588  |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 11.4          |
# | total_timesteps    | 9216          |
# | value_loss         | 54.50612      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00030279363 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 81.4          |
# | ep_reward_mean     | 81.4          |
# | explained_variance | 0.122         |
# | fps                | 644           |
# | n_updates          | 73            |
# | policy_entropy     | 0.5179155     |
# | policy_loss        | -0.0020279647 |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 11.6          |
# | total_timesteps    | 9344          |
# | value_loss         | 59.975433     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0001037077   |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 83.2           |
# | ep_reward_mean     | 83.2           |
# | explained_variance | 0.0901         |
# | fps                | 833            |
# | n_updates          | 74             |
# | policy_entropy     | 0.5043028      |
# | policy_loss        | -0.00014713022 |
# | serial_timesteps   | 9472           |
# | time_elapsed       | 11.8           |
# | total_timesteps    | 9472           |
# | value_loss         | 82.90385       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0019302486  |
# | clipfrac           | 0.03125       |
# | ep_len_mean        | 83.8          |
# | ep_reward_mean     | 83.8          |
# | explained_variance | 0.52          |
# | fps                | 848           |
# | n_updates          | 75            |
# | policy_entropy     | 0.5464457     |
# | policy_loss        | -0.0057316665 |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 11.9          |
# | total_timesteps    | 9600          |
# | value_loss         | 34.399746     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.008885331  |
# | clipfrac           | 0.14453125   |
# | ep_len_mean        | 83.8         |
# | ep_reward_mean     | 83.8         |
# | explained_variance | 0.131        |
# | fps                | 812          |
# | n_updates          | 76           |
# | policy_entropy     | 0.52925885   |
# | policy_loss        | -0.010991391 |
# | serial_timesteps   | 9728         |
# | time_elapsed       | 12.1         |
# | total_timesteps    | 9728         |
# | value_loss         | 37.3997      |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0015589036  |
# | clipfrac           | 0.017578125   |
# | ep_len_mean        | 86.3          |
# | ep_reward_mean     | 86.3          |
# | explained_variance | 0.412         |
# | fps                | 831           |
# | n_updates          | 77            |
# | policy_entropy     | 0.5481117     |
# | policy_loss        | -0.0029646053 |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 12.2          |
# | total_timesteps    | 9856          |
# | value_loss         | 42.456036     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00030306203  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 87.3           |
# | ep_reward_mean     | 87.3           |
# | explained_variance | 0.479          |
# | fps                | 820            |
# | n_updates          | 78             |
# | policy_entropy     | 0.5127315      |
# | policy_loss        | -0.00010709325 |
# | serial_timesteps   | 9984           |
# | time_elapsed       | 12.4           |
# | total_timesteps    | 9984           |
# | value_loss         | 39.33089       |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0027476957 |
# | clipfrac           | 0.033203125  |
# | ep_len_mean        | 88.3         |
# | ep_reward_mean     | 88.3         |
# | explained_variance | 0.687        |
# | fps                | 822          |
# | n_updates          | 79           |
# | policy_entropy     | 0.53631985   |
# | policy_loss        | 0.0024445055 |
# | serial_timesteps   | 10112        |
# | time_elapsed       | 12.5         |
# | total_timesteps    | 10112        |
# | value_loss         | 26.814846    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0004277927  |
# | clipfrac           | 0.00390625    |
# | ep_len_mean        | 88.3          |
# | ep_reward_mean     | 88.3          |
# | explained_variance | -0.428        |
# | fps                | 830           |
# | n_updates          | 80            |
# | policy_entropy     | 0.5573549     |
# | policy_loss        | -0.0021205982 |
# | serial_timesteps   | 10240         |
# | time_elapsed       | 12.7          |
# | total_timesteps    | 10240         |
# | value_loss         | 32.86021      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0033737381   |
# | clipfrac           | 0.029296875    |
# | ep_len_mean        | 90.6           |
# | ep_reward_mean     | 90.6           |
# | explained_variance | 0.756          |
# | fps                | 839            |
# | n_updates          | 81             |
# | policy_entropy     | 0.57969373     |
# | policy_loss        | -0.00043789484 |
# | serial_timesteps   | 10368          |
# | time_elapsed       | 12.8           |
# | total_timesteps    | 10368          |
# | value_loss         | 24.054918      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00015964825 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 91.5          |
# | ep_reward_mean     | 91.5          |
# | explained_variance | 0.0882        |
# | fps                | 836           |
# | n_updates          | 82            |
# | policy_entropy     | 0.57946885    |
# | policy_loss        | -8.524838e-05 |
# | serial_timesteps   | 10496         |
# | time_elapsed       | 13            |
# | total_timesteps    | 10496         |
# | value_loss         | 165.97908     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 1.329087e-05 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 92.4         |
# | ep_reward_mean     | 92.4         |
# | explained_variance | 0.115        |
# | fps                | 823          |
# | n_updates          | 83           |
# | policy_entropy     | 0.58916247   |
# ...
# | explained_variance | -0.00436     |
# | fps                | 798          |
# | n_updates          | 363          |
# | policy_entropy     | 0.37142938   |
# | policy_loss        | 0.0034257597 |
# | serial_timesteps   | 46464        |
# | time_elapsed       | 58.4         |
# | total_timesteps    | 46464        |
# | value_loss         | 312.0373     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0010096747  |
# | clipfrac           | 0.009765625   |
# | ep_len_mean        | 290           |
# | ep_reward_mean     | 290           |
# | explained_variance | 0.418         |
# | fps                | 782           |
# | n_updates          | 364           |
# | policy_entropy     | 0.3811994     |
# | policy_loss        | -0.0010800442 |
# | serial_timesteps   | 46592         |
# | time_elapsed       | 58.5          |
# | total_timesteps    | 46592         |
# | value_loss         | 0.005930435   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.007857337  |
# | clipfrac           | 0.078125     |
# | ep_len_mean        | 290          |
# | ep_reward_mean     | 290          |
# | explained_variance | -1.37        |
# | fps                | 813          |
# | n_updates          | 365          |
# | policy_entropy     | 0.41074428   |
# | policy_loss        | -0.006684536 |
# | serial_timesteps   | 46720        |
# | time_elapsed       | 58.7         |
# | total_timesteps    | 46720        |
# | value_loss         | 0.011113127  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.011258405  |
# | clipfrac           | 0.12695312   |
# | ep_len_mean        | 290          |
# | ep_reward_mean     | 290          |
# | explained_variance | -1.6         |
# | fps                | 818          |
# | n_updates          | 366          |
# | policy_entropy     | 0.38980657   |
# | policy_loss        | -0.012890735 |
# | serial_timesteps   | 46848        |
# | time_elapsed       | 58.8         |
# | total_timesteps    | 46848        |
# | value_loss         | 0.017687794  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0010073035  |
# | clipfrac           | 0.009765625   |
# | ep_len_mean        | 294           |
# | ep_reward_mean     | 294           |
# | explained_variance | -0.00747      |
# | fps                | 827           |
# | n_updates          | 367           |
# | policy_entropy     | 0.3750643     |
# | policy_loss        | -0.0018210601 |
# | serial_timesteps   | 46976         |
# | time_elapsed       | 59            |
# | total_timesteps    | 46976         |
# | value_loss         | 260.6393      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00029044744 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 294           |
# | ep_reward_mean     | 294           |
# | explained_variance | -4.22         |
# | fps                | 817           |
# | n_updates          | 368           |
# | policy_entropy     | 0.37403846    |
# | policy_loss        | 0.00038868433 |
# | serial_timesteps   | 47104         |
# | time_elapsed       | 59.2          |
# | total_timesteps    | 47104         |
# | value_loss         | 0.021189155   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.01619925    |
# | clipfrac           | 0.115234375   |
# | ep_len_mean        | 294           |
# | ep_reward_mean     | 294           |
# | explained_variance | -10.3         |
# | fps                | 783           |
# | n_updates          | 369           |
# | policy_entropy     | 0.35959876    |
# | policy_loss        | -0.0087375995 |
# | serial_timesteps   | 47232         |
# | time_elapsed       | 59.3          |
# | total_timesteps    | 47232         |
# | value_loss         | 0.0099142715  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0075159743  |
# | clipfrac           | 0.0859375     |
# | ep_len_mean        | 294           |
# | ep_reward_mean     | 294           |
# | explained_variance | -6.6          |
# | fps                | 800           |
# | n_updates          | 370           |
# | policy_entropy     | 0.3902316     |
# | policy_loss        | -0.0033396787 |
# | serial_timesteps   | 47360         |
# | time_elapsed       | 59.5          |
# | total_timesteps    | 47360         |
# | value_loss         | 0.010563232   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.021251839  |
# | clipfrac           | 0.20507812   |
# | ep_len_mean        | 298          |
# | ep_reward_mean     | 298          |
# | explained_variance | -0.000798    |
# | fps                | 798          |
# | n_updates          | 371          |
# | policy_entropy     | 0.43190572   |
# | policy_loss        | -0.015392472 |
# | serial_timesteps   | 47488        |
# | time_elapsed       | 59.6         |
# | total_timesteps    | 47488        |
# | value_loss         | 38.29599     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0044213403  |
# | clipfrac           | 0.041015625   |
# | ep_len_mean        | 298           |
# | ep_reward_mean     | 298           |
# | explained_variance | -12.1         |
# | fps                | 832           |
# | n_updates          | 372           |
# | policy_entropy     | 0.36994845    |
# | policy_loss        | -0.0049417075 |
# | serial_timesteps   | 47616         |
# | time_elapsed       | 59.8          |
# | total_timesteps    | 47616         |
# | value_loss         | 0.007791455   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0153953135  |
# | clipfrac           | 0.19921875    |
# | ep_len_mean        | 298           |
# | ep_reward_mean     | 298           |
# | explained_variance | -9.67         |
# | fps                | 819           |
# | n_updates          | 373           |
# | policy_entropy     | 0.39022008    |
# | policy_loss        | -0.0069901864 |
# | serial_timesteps   | 47744         |
# | time_elapsed       | 60            |
# | total_timesteps    | 47744         |
# | value_loss         | 0.007868665   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017997982  |
# | clipfrac           | 0.017578125   |
# | ep_len_mean        | 302           |
# | ep_reward_mean     | 302           |
# | explained_variance | -0.00325      |
# | fps                | 812           |
# | n_updates          | 374           |
# | policy_entropy     | 0.36667144    |
# | policy_loss        | -0.0032008376 |
# | serial_timesteps   | 47872         |
# | time_elapsed       | 60.1          |
# | total_timesteps    | 47872         |
# | value_loss         | 328.798       |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0009239847   |
# | clipfrac           | 0.01171875     |
# | ep_len_mean        | 302            |
# | ep_reward_mean     | 302            |
# | explained_variance | -11.3          |
# | fps                | 817            |
# | n_updates          | 375            |
# | policy_entropy     | 0.38312992     |
# | policy_loss        | -0.00053465995 |
# | serial_timesteps   | 48000          |
# | time_elapsed       | 60.3           |
# | total_timesteps    | 48000          |
# | value_loss         | 0.015228507    |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.010859994  |
# | clipfrac           | 0.13085938   |
# | ep_len_mean        | 302          |
# | ep_reward_mean     | 302          |
# | explained_variance | -3.84        |
# | fps                | 823          |
# | n_updates          | 376          |
# | policy_entropy     | 0.3749314    |
# | policy_loss        | -0.004372943 |
# | serial_timesteps   | 48128        |
# | time_elapsed       | 60.4         |
# | total_timesteps    | 48128        |
# | value_loss         | 0.009389121  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0040868544  |
# | clipfrac           | 0.037109375   |
# | ep_len_mean        | 302           |
# | ep_reward_mean     | 302           |
# | explained_variance | -14.9         |
# | fps                | 779           |
# | n_updates          | 377           |
# | policy_entropy     | 0.3729986     |
# | policy_loss        | -0.0067701866 |
# | serial_timesteps   | 48256         |
# | time_elapsed       | 60.6          |
# | total_timesteps    | 48256         |
# | value_loss         | 0.008000617   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.005421346  |
# | clipfrac           | 0.087890625  |
# | ep_len_mean        | 305          |
# | ep_reward_mean     | 305          |
# | explained_variance | -0.00462     |
# | fps                | 829          |
# | n_updates          | 378          |
# | policy_entropy     | 0.3713144    |
# | policy_loss        | -0.008456744 |
# | serial_timesteps   | 48384        |
# | time_elapsed       | 60.7         |
# | total_timesteps    | 48384        |
# | value_loss         | 325.4513     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.004224918   |
# | clipfrac           | 0.05078125    |
# | ep_len_mean        | 305           |
# | ep_reward_mean     | 305           |
# | explained_variance | 0.34          |
# | fps                | 830           |
# | n_updates          | 379           |
# | policy_entropy     | 0.38632342    |
# | policy_loss        | -0.0026694508 |
# | serial_timesteps   | 48512         |
# | time_elapsed       | 60.9          |
# | total_timesteps    | 48512         |
# | value_loss         | 0.018102469   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0068684937 |
# | clipfrac           | 0.060546875  |
# | ep_len_mean        | 305          |
# | ep_reward_mean     | 305          |
# | explained_variance | -1.59        |
# | fps                | 814          |
# | n_updates          | 380          |
# | policy_entropy     | 0.37141895   |
# | policy_loss        | -0.011971271 |
# | serial_timesteps   | 48640        |
# | time_elapsed       | 61.1         |
# | total_timesteps    | 48640        |
# | value_loss         | 0.037369926  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.015177518  |
# | clipfrac           | 0.13671875   |
# | ep_len_mean        | 305          |
# | ep_reward_mean     | 305          |
# | explained_variance | 0.762        |
# | fps                | 812          |
# | n_updates          | 381          |
# | policy_entropy     | 0.41470546   |
# | policy_loss        | -0.009115024 |
# | serial_timesteps   | 48768        |
# | time_elapsed       | 61.2         |
# | total_timesteps    | 48768        |
# | value_loss         | 0.021138096  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0034121256  |
# | clipfrac           | 0.041015625   |
# | ep_len_mean        | 309           |
# | ep_reward_mean     | 309           |
# | explained_variance | 0.0476        |
# | fps                | 815           |
# | n_updates          | 382           |
# | policy_entropy     | 0.39418766    |
# | policy_loss        | -0.0007110308 |
# | serial_timesteps   | 48896         |
# | time_elapsed       | 61.4          |
# | total_timesteps    | 48896         |
# | value_loss         | 307.12506     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0069144815 |
# | clipfrac           | 0.115234375  |
# | ep_len_mean        | 309          |
# | ep_reward_mean     | 309          |
# | explained_variance | -2.45        |
# | fps                | 807          |
# | n_updates          | 383          |
# | policy_entropy     | 0.38316748   |
# | policy_loss        | -0.003796502 |
# | serial_timesteps   | 49024        |
# | time_elapsed       | 61.5         |
# | total_timesteps    | 49024        |
# | value_loss         | 0.0084610125 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.007122765  |
# | clipfrac           | 0.08984375   |
# | ep_len_mean        | 309          |
# | ep_reward_mean     | 309          |
# | explained_variance | -1.74        |
# | fps                | 844          |
# | n_updates          | 384          |
# | policy_entropy     | 0.36752048   |
# | policy_loss        | -0.012373577 |
# | serial_timesteps   | 49152        |
# | time_elapsed       | 61.7         |
# | total_timesteps    | 49152        |
# | value_loss         | 0.00759626   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.008336948   |
# | clipfrac           | 0.080078125   |
# | ep_len_mean        | 309           |
# | ep_reward_mean     | 309           |
# | explained_variance | 0.61          |
# | fps                | 849           |
# | n_updates          | 385           |
# | policy_entropy     | 0.3679564     |
# | policy_loss        | -0.0041853036 |
# | serial_timesteps   | 49280         |
# | time_elapsed       | 61.8          |
# | total_timesteps    | 49280         |
# | value_loss         | 0.004501955   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0025894947  |
# | clipfrac           | 0.0234375     |
# | ep_len_mean        | 312           |
# | ep_reward_mean     | 312           |
# | explained_variance | 0.00134       |
# | fps                | 839           |
# | n_updates          | 386           |
# | policy_entropy     | 0.41041505    |
# | policy_loss        | -0.0018442688 |
# | serial_timesteps   | 49408         |
# | time_elapsed       | 62            |
# | total_timesteps    | 49408         |
# | value_loss         | 321.33817     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00810047    |
# | clipfrac           | 0.12695312    |
# | ep_len_mean        | 312           |
# | ep_reward_mean     | 312           |
# | explained_variance | 0.847         |
# | fps                | 877           |
# | n_updates          | 387           |
# | policy_entropy     | 0.42314833    |
# | policy_loss        | -0.0064795087 |
# | serial_timesteps   | 49536         |
# | time_elapsed       | 62.1          |
# | total_timesteps    | 49536         |
# | value_loss         | 0.017346084   |
# --------------------------------------
# ------------------------------------
# | approxkl           | 0.012786363 |
# | clipfrac           | 0.11328125  |
# | ep_len_mean        | 312         |
# | ep_reward_mean     | 312         |
# | explained_variance | -1.25       |
# | fps                | 836         |
# | n_updates          | 388         |
# | policy_entropy     | 0.4088023   |
# | policy_loss        | -0.00734141 |
# | serial_timesteps   | 49664       |
# | time_elapsed       | 62.3        |
# | total_timesteps    | 49664       |
# | value_loss         | 0.17325507  |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.002168411  |
# | clipfrac           | 0.021484375  |
# | ep_len_mean        | 312          |
# | ep_reward_mean     | 312          |
# | explained_variance | -0.549       |
# | fps                | 832          |
# | n_updates          | 389          |
# | policy_entropy     | 0.42412362   |
# | policy_loss        | 0.0029362175 |
# | serial_timesteps   | 49792        |
# | time_elapsed       | 62.4         |
# | total_timesteps    | 49792        |
# | value_loss         | 0.042799614  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.015358709  |
# | clipfrac           | 0.1875       |
# | ep_len_mean        | 315          |
# | ep_reward_mean     | 315          |
# | explained_variance | 0.00172      |
# | fps                | 789          |
# | n_updates          | 390          |
# | policy_entropy     | 0.39766082   |
# | policy_loss        | 0.0023935658 |
# | serial_timesteps   | 49920        |
# | time_elapsed       | 62.6         |
# | total_timesteps    | 49920        |
# | value_loss         | 320.9739     |
# -------------------------------------

# %%
# Enjoy trained agent
obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=False)
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
        obs = env.reset()
env.close()
